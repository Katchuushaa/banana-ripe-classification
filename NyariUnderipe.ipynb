# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as gas

# %%
def nyaripisangunderipe(gambar):
     # Konversi gambar ke ruang warna RGB
    image_rgb = cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB)

   # Definisikan rentang nilai warna kuning untuk segmentasi buah pisang
    lower_yellow = np.array([0, 0, 0])
    upper_yellow = np.array([255, 255, 255])

    # Buat mask berdasarkan rentang nilai warna kuning
    masked = cv2.inRange(image_rgb, lower_yellow, upper_yellow)
    
    # Menghitung jumlah piksel kuning dalam mask
    yellow_pixels = cv2.countNonZero(masked)
    
    # Mencari kontur dari mask
    contours, _ = cv2.findContours(masked, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    max_area = 0
    max_contour = None
    
    # Mencari kontur kuning dengan luas terbesar
    for contour in contours:
        area = cv2.contourArea(contour)
        
        if area > max_area:
            max_area = area
            max_contour = contour
    
    # Mengekstrak bounding box dari kontur terbesar
    x, y, w, h = cv2.boundingRect(max_contour)
    
    # Menambahkan margin pada bounding rectangle
    margin = 50
    x1 = max(0, x - margin)
    y1 = max(0, y - margin)
    x2 = min(gambar.shape[1], x + w + margin)
    y2 = min(gambar.shape[0], y + h + margin)
    
    # Menghitung koordinat tengah bounding box
    center_x = (x1 + x2) // 2
    center_y = (y1 + y2) // 2
    
    # Mengubah posisi kotak berdasarkan koordinat tengah bounding box
    kotak_width = 50
    kotak_height = 70
    kotak_x1 = max(0, center_x - kotak_width // 2)
    kotak_y1 = max(0, center_y - kotak_height // 2)
    kotak_x2 = min(gambar.shape[1], center_x + kotak_width // 2)
    kotak_y2 = min(gambar.shape[0], center_y + kotak_height // 2)
    
    # Membuat kotak dengan ukuran 100x200 di sekitar area dengan kuning paling banyak
    kotak = np.zeros((kotak_height, kotak_width, 3), dtype=np.uint8)
    kotak[:kotak_y2-kotak_y1, :kotak_x2-kotak_x1] = gambar[kotak_y1:kotak_y1+kotak_y2-kotak_y1, kotak_x1:kotak_x1+kotak_x2-kotak_x1]

    return kotak

# %%
def segmentasi_buah_pisang(input_dir, output_dir):
    # Buat direktori output jika belum ada
    os.makedirs(output_dir, exist_ok=True)

    # Dapatkan daftar file dalam direktori input
    file_list = os.listdir(input_dir)

    # Melakukan segmentasi pada setiap file gambar
    for file_name in file_list:
        # Baca gambar
        gambar = cv2.imread(os.path.join(input_dir, file_name))

        # Memeriksa jumlah piksel dengan metode segmentasi HSV
        segmented_img = nyaripisangunderipe(gambar)

        # Ubah nama file hasil segmentasi
        segmented_file_name = "segmented_" + file_name

        # Simpan hasil segmentasi ke direktori output
        cv2.imwrite(os.path.join(output_dir, segmented_file_name), segmented_img)

        print(f"Segmentasi selesai: {file_name} -> {segmented_file_name}")

# Contoh penggunaan
input_directory = "T:/PCD/Banana_Condensed_Three_Cat/underripe"
output_directory = "T:/PCD/Banana_Condensed_Three_Cat/segurp"
segmentasi_buah_pisang(input_directory, output_directory)
# Out:
# Segmentasi selesai: underripe (10).jpg -> segmented_underripe (10).jpg
# Segmentasi selesai: underripe (100).jpg -> segmented_underripe (100).jpg
# Segmentasi selesai: underripe (101).jpg -> segmented_underripe (101).jpg
# Segmentasi selesai: underripe (102).jpg -> segmented_underripe (102).jpg
# Segmentasi selesai: underripe (103).jpg -> segmented_underripe (103).jpg
# Segmentasi selesai: underripe (104).jpg -> segmented_underripe (104).jpg
# Segmentasi selesai: underripe (105).jpg -> segmented_underripe (105).jpg
# Segmentasi selesai: underripe (106).jpg -> segmented_underripe (106).jpg
# Segmentasi selesai: underripe (107).jpg -> segmented_underripe (107).jpg
# Segmentasi selesai: underripe (108).jpg -> segmented_underripe (108).jpg
# Segmentasi selesai: underripe (109).jpg -> segmented_underripe (109).jpg
# Segmentasi selesai: underripe (11).jpg -> segmented_underripe (11).jpg
# Segmentasi selesai: underripe (110).jpg -> segmented_underripe (110).jpg
# Segmentasi selesai: underripe (111).jpg -> segmented_underripe (111).jpg
# Segmentasi selesai: underripe (112).jpg -> segmented_underripe (112).jpg
# Segmentasi selesai: underripe (113).jpg -> segmented_underripe (113).jpg
# Segmentasi selesai: underripe (114).jpg -> segmented_underripe (114).jpg
# Segmentasi selesai: underripe (115).jpg -> segmented_underripe (115).jpg
# Segmentasi selesai: underripe (116).jpg -> segmented_underripe (116).jpg
# Segmentasi selesai: underripe (117).jpg -> segmented_underripe (117).jpg
# Segmentasi selesai: underripe (118).jpg -> segmented_underripe (118).jpg
# Segmentasi selesai: underripe (119).jpg -> segmented_underripe (119).jpg
# Segmentasi selesai: underripe (12).jpg -> segmented_underripe (12).jpg
# Segmentasi selesai: underripe (120).jpg -> segmented_underripe (120).jpg
# Segmentasi selesai: underripe (121).jpg -> segmented_underripe (121).jpg
# Segmentasi selesai: underripe (122).jpg -> segmented_underripe (122).jpg
# Segmentasi selesai: underripe (123).jpg -> segmented_underripe (123).jpg
# Segmentasi selesai: underripe (124).jpg -> segmented_underripe (124).jpg
# Segmentasi selesai: underripe (125).jpg -> segmented_underripe (125).jpg
# Segmentasi selesai: underripe (126).jpg -> segmented_underripe (126).jpg
# Segmentasi selesai: underripe (127).jpg -> segmented_underripe (127).jpg
# Segmentasi selesai: underripe (128).jpg -> segmented_underripe (128).jpg
# Segmentasi selesai: underripe (129).jpg -> segmented_underripe (129).jpg
# Segmentasi selesai: underripe (13).jpg -> segmented_underripe (13).jpg
# Segmentasi selesai: underripe (130).jpg -> segmented_underripe (130).jpg
# Segmentasi selesai: underripe (131).jpg -> segmented_underripe (131).jpg
# Segmentasi selesai: underripe (132).jpg -> segmented_underripe (132).jpg
# Segmentasi selesai: underripe (133).jpg -> segmented_underripe (133).jpg
# Segmentasi selesai: underripe (134).jpg -> segmented_underripe (134).jpg
# Segmentasi selesai: underripe (135).jpg -> segmented_underripe (135).jpg
# Segmentasi selesai: underripe (136).jpg -> segmented_underripe (136).jpg
# Segmentasi selesai: underripe (137).jpg -> segmented_underripe (137).jpg
# Segmentasi selesai: underripe (138).jpg -> segmented_underripe (138).jpg
# Segmentasi selesai: underripe (139).jpg -> segmented_underripe (139).jpg
# Segmentasi selesai: underripe (14).jpg -> segmented_underripe (14).jpg
# Segmentasi selesai: underripe (140).jpg -> segmented_underripe (140).jpg
# Segmentasi selesai: underripe (141).jpg -> segmented_underripe (141).jpg
# Segmentasi selesai: underripe (142).jpg -> segmented_underripe (142).jpg
# Segmentasi selesai: underripe (143).jpg -> segmented_underripe (143).jpg
# Segmentasi selesai: underripe (144).jpg -> segmented_underripe (144).jpg
# Segmentasi selesai: underripe (145).jpg -> segmented_underripe (145).jpg
# Segmentasi selesai: underripe (146).jpg -> segmented_underripe (146).jpg
# Segmentasi selesai: underripe (147).jpg -> segmented_underripe (147).jpg
# Segmentasi selesai: underripe (148).jpg -> segmented_underripe (148).jpg
# Segmentasi selesai: underripe (149).jpg -> segmented_underripe (149).jpg
# Segmentasi selesai: underripe (15).jpg -> segmented_underripe (15).jpg
# Segmentasi selesai: underripe (150).jpg -> segmented_underripe (150).jpg
# Segmentasi selesai: underripe (151).jpg -> segmented_underripe (151).jpg
# Segmentasi selesai: underripe (152).jpg -> segmented_underripe (152).jpg
# Segmentasi selesai: underripe (153).jpg -> segmented_underripe (153).jpg
# Segmentasi selesai: underripe (154).jpg -> segmented_underripe (154).jpg
# Segmentasi selesai: underripe (155).jpg -> segmented_underripe (155).jpg
# Segmentasi selesai: underripe (156).jpg -> segmented_underripe (156).jpg
# Segmentasi selesai: underripe (157).jpg -> segmented_underripe (157).jpg
# Segmentasi selesai: underripe (158).jpg -> segmented_underripe (158).jpg
# Segmentasi selesai: underripe (159).jpg -> segmented_underripe (159).jpg
# Segmentasi selesai: underripe (16).jpg -> segmented_underripe (16).jpg
# Segmentasi selesai: underripe (160).jpg -> segmented_underripe (160).jpg
# Segmentasi selesai: underripe (161).jpg -> segmented_underripe (161).jpg
# Segmentasi selesai: underripe (162).jpg -> segmented_underripe (162).jpg
# Segmentasi selesai: underripe (163).jpg -> segmented_underripe (163).jpg
# Segmentasi selesai: underripe (164).jpg -> segmented_underripe (164).jpg
# Segmentasi selesai: underripe (165).jpg -> segmented_underripe (165).jpg
# Segmentasi selesai: underripe (166).jpg -> segmented_underripe (166).jpg
# Segmentasi selesai: underripe (167).jpg -> segmented_underripe (167).jpg
# Segmentasi selesai: underripe (168).jpg -> segmented_underripe (168).jpg
# Segmentasi selesai: underripe (169).jpg -> segmented_underripe (169).jpg
# Segmentasi selesai: underripe (17).jpg -> segmented_underripe (17).jpg
# Segmentasi selesai: underripe (170).jpg -> segmented_underripe (170).jpg
# Segmentasi selesai: underripe (171).jpg -> segmented_underripe (171).jpg
# Segmentasi selesai: underripe (172).jpg -> segmented_underripe (172).jpg
# Segmentasi selesai: underripe (173).jpg -> segmented_underripe (173).jpg
# Segmentasi selesai: underripe (174).jpg -> segmented_underripe (174).jpg
# Segmentasi selesai: underripe (175).jpg -> segmented_underripe (175).jpg
# Segmentasi selesai: underripe (176).jpg -> segmented_underripe (176).jpg
# Segmentasi selesai: underripe (177).jpg -> segmented_underripe (177).jpg
# Segmentasi selesai: underripe (178).jpg -> segmented_underripe (178).jpg
# Segmentasi selesai: underripe (179).jpg -> segmented_underripe (179).jpg
# Segmentasi selesai: underripe (18).jpg -> segmented_underripe (18).jpg
# Segmentasi selesai: underripe (180).jpg -> segmented_underripe (180).jpg
# Segmentasi selesai: underripe (181).jpg -> segmented_underripe (181).jpg
# Segmentasi selesai: underripe (182).jpg -> segmented_underripe (182).jpg
# Segmentasi selesai: underripe (183).jpg -> segmented_underripe (183).jpg
# Segmentasi selesai: underripe (184).jpg -> segmented_underripe (184).jpg
# Segmentasi selesai: underripe (185).jpg -> segmented_underripe (185).jpg
# Segmentasi selesai: underripe (186).jpg -> segmented_underripe (186).jpg
# Segmentasi selesai: underripe (187).jpg -> segmented_underripe (187).jpg
# Segmentasi selesai: underripe (188).jpg -> segmented_underripe (188).jpg
# Segmentasi selesai: underripe (189).jpg -> segmented_underripe (189).jpg
# Segmentasi selesai: underripe (19).jpg -> segmented_underripe (19).jpg
# Segmentasi selesai: underripe (190).jpg -> segmented_underripe (190).jpg
# Segmentasi selesai: underripe (191).jpg -> segmented_underripe (191).jpg
# Segmentasi selesai: underripe (192).jpg -> segmented_underripe (192).jpg
# Segmentasi selesai: underripe (193).jpg -> segmented_underripe (193).jpg
# Segmentasi selesai: underripe (194).jpg -> segmented_underripe (194).jpg
# Segmentasi selesai: underripe (195).jpg -> segmented_underripe (195).jpg
# Segmentasi selesai: underripe (196).jpg -> segmented_underripe (196).jpg
# Segmentasi selesai: underripe (197).jpg -> segmented_underripe (197).jpg
# Segmentasi selesai: underripe (198).jpg -> segmented_underripe (198).jpg
# Segmentasi selesai: underripe (199).jpg -> segmented_underripe (199).jpg
# Segmentasi selesai: underripe (2).jpg -> segmented_underripe (2).jpg
# Segmentasi selesai: underripe (20).jpg -> segmented_underripe (20).jpg
# Segmentasi selesai: underripe (200).jpg -> segmented_underripe (200).jpg
# Segmentasi selesai: underripe (201).jpg -> segmented_underripe (201).jpg
# Segmentasi selesai: underripe (202).jpg -> segmented_underripe (202).jpg
# Segmentasi selesai: underripe (203).jpg -> segmented_underripe (203).jpg
# Segmentasi selesai: underripe (204).jpg -> segmented_underripe (204).jpg
# Segmentasi selesai: underripe (205).jpg -> segmented_underripe (205).jpg
# Segmentasi selesai: underripe (206).jpg -> segmented_underripe (206).jpg
# Segmentasi selesai: underripe (207).jpg -> segmented_underripe (207).jpg
# Segmentasi selesai: underripe (208).jpg -> segmented_underripe (208).jpg
# Segmentasi selesai: underripe (209).jpg -> segmented_underripe (209).jpg
# Segmentasi selesai: underripe (21).jpg -> segmented_underripe (21).jpg
# Segmentasi selesai: underripe (210).jpg -> segmented_underripe (210).jpg
# Segmentasi selesai: underripe (211).jpg -> segmented_underripe (211).jpg
# Segmentasi selesai: underripe (212).jpg -> segmented_underripe (212).jpg
# Segmentasi selesai: underripe (213).jpg -> segmented_underripe (213).jpg
# Segmentasi selesai: underripe (214).jpg -> segmented_underripe (214).jpg
# Segmentasi selesai: underripe (215).jpg -> segmented_underripe (215).jpg
# Segmentasi selesai: underripe (216).jpg -> segmented_underripe (216).jpg
# Segmentasi selesai: underripe (217).jpg -> segmented_underripe (217).jpg
# Segmentasi selesai: underripe (218).jpg -> segmented_underripe (218).jpg
# Segmentasi selesai: underripe (219).jpg -> segmented_underripe (219).jpg
# Segmentasi selesai: underripe (22).jpg -> segmented_underripe (22).jpg
# Segmentasi selesai: underripe (220).jpg -> segmented_underripe (220).jpg
# Segmentasi selesai: underripe (221).jpg -> segmented_underripe (221).jpg
# Segmentasi selesai: underripe (222).jpg -> segmented_underripe (222).jpg
# Segmentasi selesai: underripe (223).jpg -> segmented_underripe (223).jpg
# Segmentasi selesai: underripe (224).jpg -> segmented_underripe (224).jpg
# Segmentasi selesai: underripe (225).jpg -> segmented_underripe (225).jpg
# Segmentasi selesai: underripe (226).jpg -> segmented_underripe (226).jpg
# Segmentasi selesai: underripe (227).jpg -> segmented_underripe (227).jpg
# Segmentasi selesai: underripe (228).jpg -> segmented_underripe (228).jpg
# Segmentasi selesai: underripe (229).jpg -> segmented_underripe (229).jpg
# Segmentasi selesai: underripe (23).jpg -> segmented_underripe (23).jpg
# Segmentasi selesai: underripe (230).jpg -> segmented_underripe (230).jpg
# Segmentasi selesai: underripe (231).jpg -> segmented_underripe (231).jpg
# Segmentasi selesai: underripe (232).jpg -> segmented_underripe (232).jpg
# Segmentasi selesai: underripe (233).jpg -> segmented_underripe (233).jpg
# Segmentasi selesai: underripe (234).jpg -> segmented_underripe (234).jpg
# Segmentasi selesai: underripe (235).jpg -> segmented_underripe (235).jpg
# Segmentasi selesai: underripe (236).jpg -> segmented_underripe (236).jpg
# Segmentasi selesai: underripe (237).jpg -> segmented_underripe (237).jpg
# Segmentasi selesai: underripe (238).jpg -> segmented_underripe (238).jpg
# Segmentasi selesai: underripe (239).jpg -> segmented_underripe (239).jpg
# Segmentasi selesai: underripe (24).jpg -> segmented_underripe (24).jpg
# Segmentasi selesai: underripe (240).jpg -> segmented_underripe (240).jpg
# Segmentasi selesai: underripe (241).jpg -> segmented_underripe (241).jpg
# Segmentasi selesai: underripe (242).jpg -> segmented_underripe (242).jpg
# Segmentasi selesai: underripe (243).jpg -> segmented_underripe (243).jpg
# Segmentasi selesai: underripe (244).jpg -> segmented_underripe (244).jpg
# Segmentasi selesai: underripe (245).jpg -> segmented_underripe (245).jpg
# Segmentasi selesai: underripe (246).jpg -> segmented_underripe (246).jpg
# Segmentasi selesai: underripe (247).jpg -> segmented_underripe (247).jpg
# Segmentasi selesai: underripe (248).jpg -> segmented_underripe (248).jpg
# Segmentasi selesai: underripe (249).jpg -> segmented_underripe (249).jpg
# Segmentasi selesai: underripe (25).jpg -> segmented_underripe (25).jpg
# Segmentasi selesai: underripe (250).jpg -> segmented_underripe (250).jpg
# Segmentasi selesai: underripe (251).jpg -> segmented_underripe (251).jpg
# Segmentasi selesai: underripe (252).jpg -> segmented_underripe (252).jpg
# Segmentasi selesai: underripe (253).jpg -> segmented_underripe (253).jpg
# Segmentasi selesai: underripe (254).jpg -> segmented_underripe (254).jpg
# Segmentasi selesai: underripe (255).jpg -> segmented_underripe (255).jpg
# Segmentasi selesai: underripe (256).jpg -> segmented_underripe (256).jpg
# Segmentasi selesai: underripe (257).jpg -> segmented_underripe (257).jpg
# Segmentasi selesai: underripe (258).jpg -> segmented_underripe (258).jpg
# Segmentasi selesai: underripe (259).jpg -> segmented_underripe (259).jpg
# Segmentasi selesai: underripe (26).jpg -> segmented_underripe (26).jpg
# Segmentasi selesai: underripe (260).jpg -> segmented_underripe (260).jpg
# Segmentasi selesai: underripe (261).jpg -> segmented_underripe (261).jpg
# Segmentasi selesai: underripe (262).jpg -> segmented_underripe (262).jpg
# Segmentasi selesai: underripe (263).jpg -> segmented_underripe (263).jpg
# Segmentasi selesai: underripe (264).jpg -> segmented_underripe (264).jpg
# Segmentasi selesai: underripe (265).jpg -> segmented_underripe (265).jpg
# Segmentasi selesai: underripe (266).jpg -> segmented_underripe (266).jpg
# Segmentasi selesai: underripe (267).jpg -> segmented_underripe (267).jpg
# Segmentasi selesai: underripe (268).jpg -> segmented_underripe (268).jpg
# Segmentasi selesai: underripe (269).jpg -> segmented_underripe (269).jpg
# Segmentasi selesai: underripe (27).jpg -> segmented_underripe (27).jpg
# Segmentasi selesai: underripe (270).jpg -> segmented_underripe (270).jpg
# Segmentasi selesai: underripe (271).jpg -> segmented_underripe (271).jpg
# Segmentasi selesai: underripe (272).jpg -> segmented_underripe (272).jpg
# Segmentasi selesai: underripe (273).jpg -> segmented_underripe (273).jpg
# Segmentasi selesai: underripe (274).jpg -> segmented_underripe (274).jpg
# Segmentasi selesai: underripe (275).jpg -> segmented_underripe (275).jpg
# Segmentasi selesai: underripe (276).jpg -> segmented_underripe (276).jpg
# Segmentasi selesai: underripe (277).jpg -> segmented_underripe (277).jpg
# Segmentasi selesai: underripe (278).jpg -> segmented_underripe (278).jpg
# Segmentasi selesai: underripe (279).jpg -> segmented_underripe (279).jpg
# Segmentasi selesai: underripe (28).jpg -> segmented_underripe (28).jpg
# Segmentasi selesai: underripe (280).jpg -> segmented_underripe (280).jpg
# Segmentasi selesai: underripe (281).jpg -> segmented_underripe (281).jpg
# Segmentasi selesai: underripe (282).jpg -> segmented_underripe (282).jpg
# Segmentasi selesai: underripe (283).jpg -> segmented_underripe (283).jpg
# Segmentasi selesai: underripe (284).jpg -> segmented_underripe (284).jpg
# Segmentasi selesai: underripe (285).jpg -> segmented_underripe (285).jpg
# Segmentasi selesai: underripe (286).jpg -> segmented_underripe (286).jpg
# Segmentasi selesai: underripe (287).jpg -> segmented_underripe (287).jpg
# Segmentasi selesai: underripe (288).jpg -> segmented_underripe (288).jpg
# Segmentasi selesai: underripe (289).jpg -> segmented_underripe (289).jpg
# Segmentasi selesai: underripe (29).jpg -> segmented_underripe (29).jpg
# Segmentasi selesai: underripe (290).jpg -> segmented_underripe (290).jpg
# Segmentasi selesai: underripe (291).jpg -> segmented_underripe (291).jpg
# Segmentasi selesai: underripe (292).jpg -> segmented_underripe (292).jpg
# Segmentasi selesai: underripe (293).jpg -> segmented_underripe (293).jpg
# Segmentasi selesai: underripe (294).jpg -> segmented_underripe (294).jpg
# Segmentasi selesai: underripe (295).jpg -> segmented_underripe (295).jpg
# Segmentasi selesai: underripe (296).jpg -> segmented_underripe (296).jpg
# Segmentasi selesai: underripe (297).jpg -> segmented_underripe (297).jpg
# Segmentasi selesai: underripe (298).jpg -> segmented_underripe (298).jpg
# Segmentasi selesai: underripe (299).jpg -> segmented_underripe (299).jpg
# Segmentasi selesai: underripe (3).jpg -> segmented_underripe (3).jpg
# Segmentasi selesai: underripe (30).jpg -> segmented_underripe (30).jpg
# Segmentasi selesai: underripe (300).jpg -> segmented_underripe (300).jpg
# Segmentasi selesai: underripe (301).jpg -> segmented_underripe (301).jpg
# Segmentasi selesai: underripe (302).jpg -> segmented_underripe (302).jpg
# Segmentasi selesai: underripe (303).jpg -> segmented_underripe (303).jpg
# Segmentasi selesai: underripe (304).jpg -> segmented_underripe (304).jpg
# Segmentasi selesai: underripe (305).jpg -> segmented_underripe (305).jpg
# Segmentasi selesai: underripe (306).jpg -> segmented_underripe (306).jpg
# Segmentasi selesai: underripe (307).jpg -> segmented_underripe (307).jpg
# Segmentasi selesai: underripe (308).jpg -> segmented_underripe (308).jpg
# Segmentasi selesai: underripe (309).jpg -> segmented_underripe (309).jpg
# Segmentasi selesai: underripe (31).jpg -> segmented_underripe (31).jpg
# Segmentasi selesai: underripe (310).jpg -> segmented_underripe (310).jpg
# Segmentasi selesai: underripe (311).jpg -> segmented_underripe (311).jpg
# Segmentasi selesai: underripe (312).jpg -> segmented_underripe (312).jpg
# Segmentasi selesai: underripe (313).jpg -> segmented_underripe (313).jpg
# Segmentasi selesai: underripe (314).jpg -> segmented_underripe (314).jpg
# Segmentasi selesai: underripe (315).jpg -> segmented_underripe (315).jpg
# Segmentasi selesai: underripe (316).jpg -> segmented_underripe (316).jpg
# Segmentasi selesai: underripe (317).jpg -> segmented_underripe (317).jpg
# Segmentasi selesai: underripe (318).jpg -> segmented_underripe (318).jpg
# Segmentasi selesai: underripe (319).jpg -> segmented_underripe (319).jpg
# Segmentasi selesai: underripe (32).jpg -> segmented_underripe (32).jpg
# Segmentasi selesai: underripe (320).jpg -> segmented_underripe (320).jpg
# Segmentasi selesai: underripe (321).jpg -> segmented_underripe (321).jpg
# Segmentasi selesai: underripe (322).jpg -> segmented_underripe (322).jpg
# Segmentasi selesai: underripe (323).jpg -> segmented_underripe (323).jpg
# Segmentasi selesai: underripe (324).jpg -> segmented_underripe (324).jpg
# Segmentasi selesai: underripe (325).jpg -> segmented_underripe (325).jpg
# Segmentasi selesai: underripe (326).jpg -> segmented_underripe (326).jpg
# Segmentasi selesai: underripe (327).jpg -> segmented_underripe (327).jpg
# Segmentasi selesai: underripe (328).jpg -> segmented_underripe (328).jpg
# Segmentasi selesai: underripe (329).jpg -> segmented_underripe (329).jpg
# Segmentasi selesai: underripe (33).jpg -> segmented_underripe (33).jpg
# Segmentasi selesai: underripe (330).jpg -> segmented_underripe (330).jpg
# Segmentasi selesai: underripe (331).jpg -> segmented_underripe (331).jpg
# Segmentasi selesai: underripe (332).jpg -> segmented_underripe (332).jpg
# Segmentasi selesai: underripe (333).jpg -> segmented_underripe (333).jpg
# Segmentasi selesai: underripe (334).jpg -> segmented_underripe (334).jpg
# Segmentasi selesai: underripe (335).jpg -> segmented_underripe (335).jpg
# Segmentasi selesai: underripe (336).jpg -> segmented_underripe (336).jpg
# Segmentasi selesai: underripe (337).jpg -> segmented_underripe (337).jpg
# Segmentasi selesai: underripe (338).jpg -> segmented_underripe (338).jpg
# Segmentasi selesai: underripe (339).jpg -> segmented_underripe (339).jpg
# Segmentasi selesai: underripe (34).jpg -> segmented_underripe (34).jpg
# Segmentasi selesai: underripe (340).jpg -> segmented_underripe (340).jpg
# Segmentasi selesai: underripe (341).jpg -> segmented_underripe (341).jpg
# Segmentasi selesai: underripe (342).jpg -> segmented_underripe (342).jpg
# Segmentasi selesai: underripe (343).jpg -> segmented_underripe (343).jpg
# Segmentasi selesai: underripe (344).jpg -> segmented_underripe (344).jpg
# Segmentasi selesai: underripe (345).jpg -> segmented_underripe (345).jpg
# Segmentasi selesai: underripe (346).jpg -> segmented_underripe (346).jpg
# Segmentasi selesai: underripe (347).jpg -> segmented_underripe (347).jpg
# Segmentasi selesai: underripe (348).jpg -> segmented_underripe (348).jpg
# Segmentasi selesai: underripe (349).jpg -> segmented_underripe (349).jpg
# Segmentasi selesai: underripe (35).jpg -> segmented_underripe (35).jpg
# Segmentasi selesai: underripe (350).jpg -> segmented_underripe (350).jpg
# Segmentasi selesai: underripe (351).jpg -> segmented_underripe (351).jpg
# Segmentasi selesai: underripe (352).jpg -> segmented_underripe (352).jpg
# Segmentasi selesai: underripe (353).jpg -> segmented_underripe (353).jpg
# Segmentasi selesai: underripe (354).jpg -> segmented_underripe (354).jpg
# Segmentasi selesai: underripe (355).jpg -> segmented_underripe (355).jpg
# Segmentasi selesai: underripe (356).jpg -> segmented_underripe (356).jpg
# Segmentasi selesai: underripe (357).jpg -> segmented_underripe (357).jpg
# Segmentasi selesai: underripe (358).jpg -> segmented_underripe (358).jpg
# Segmentasi selesai: underripe (359).jpg -> segmented_underripe (359).jpg
# Segmentasi selesai: underripe (36).jpg -> segmented_underripe (36).jpg
# Segmentasi selesai: underripe (360).jpg -> segmented_underripe (360).jpg
# Segmentasi selesai: underripe (361).jpg -> segmented_underripe (361).jpg
# Segmentasi selesai: underripe (362).jpg -> segmented_underripe (362).jpg
# Segmentasi selesai: underripe (363).jpg -> segmented_underripe (363).jpg
# Segmentasi selesai: underripe (364).jpg -> segmented_underripe (364).jpg
# Segmentasi selesai: underripe (365).jpg -> segmented_underripe (365).jpg
# Segmentasi selesai: underripe (366).jpg -> segmented_underripe (366).jpg
# Segmentasi selesai: underripe (367).jpg -> segmented_underripe (367).jpg
# Segmentasi selesai: underripe (368).jpg -> segmented_underripe (368).jpg
# Segmentasi selesai: underripe (369).jpg -> segmented_underripe (369).jpg
# Segmentasi selesai: underripe (37).jpg -> segmented_underripe (37).jpg
# Segmentasi selesai: underripe (370).jpg -> segmented_underripe (370).jpg
# Segmentasi selesai: underripe (371).jpg -> segmented_underripe (371).jpg
# Segmentasi selesai: underripe (372).jpg -> segmented_underripe (372).jpg
# Segmentasi selesai: underripe (373).jpg -> segmented_underripe (373).jpg
# Segmentasi selesai: underripe (374).jpg -> segmented_underripe (374).jpg
# Segmentasi selesai: underripe (375).jpg -> segmented_underripe (375).jpg
# Segmentasi selesai: underripe (376).jpg -> segmented_underripe (376).jpg
# Segmentasi selesai: underripe (377).jpg -> segmented_underripe (377).jpg
# Segmentasi selesai: underripe (378).jpg -> segmented_underripe (378).jpg
# Segmentasi selesai: underripe (379).jpg -> segmented_underripe (379).jpg
# Segmentasi selesai: underripe (38).jpg -> segmented_underripe (38).jpg
# Segmentasi selesai: underripe (380).jpg -> segmented_underripe (380).jpg
# Segmentasi selesai: underripe (381).jpg -> segmented_underripe (381).jpg
# Segmentasi selesai: underripe (382).jpg -> segmented_underripe (382).jpg
# Segmentasi selesai: underripe (383).jpg -> segmented_underripe (383).jpg
# Segmentasi selesai: underripe (384).jpg -> segmented_underripe (384).jpg
# Segmentasi selesai: underripe (385).jpg -> segmented_underripe (385).jpg
# Segmentasi selesai: underripe (386).jpg -> segmented_underripe (386).jpg
# Segmentasi selesai: underripe (387).jpg -> segmented_underripe (387).jpg
# Segmentasi selesai: underripe (388).jpg -> segmented_underripe (388).jpg
# Segmentasi selesai: underripe (389).jpg -> segmented_underripe (389).jpg
# Segmentasi selesai: underripe (39).jpg -> segmented_underripe (39).jpg
# Segmentasi selesai: underripe (390).jpg -> segmented_underripe (390).jpg
# Segmentasi selesai: underripe (391).jpg -> segmented_underripe (391).jpg
# Segmentasi selesai: underripe (392).jpg -> segmented_underripe (392).jpg
# Segmentasi selesai: underripe (393).jpg -> segmented_underripe (393).jpg
# Segmentasi selesai: underripe (394).jpg -> segmented_underripe (394).jpg
# Segmentasi selesai: underripe (395).jpg -> segmented_underripe (395).jpg
# Segmentasi selesai: underripe (396).jpg -> segmented_underripe (396).jpg
# Segmentasi selesai: underripe (397).jpg -> segmented_underripe (397).jpg
# Segmentasi selesai: underripe (398).jpg -> segmented_underripe (398).jpg
# Segmentasi selesai: underripe (399).jpg -> segmented_underripe (399).jpg
# Segmentasi selesai: underripe (4).jpg -> segmented_underripe (4).jpg
# Segmentasi selesai: underripe (40).jpg -> segmented_underripe (40).jpg
# Segmentasi selesai: underripe (400).jpg -> segmented_underripe (400).jpg
# Segmentasi selesai: underripe (401).jpg -> segmented_underripe (401).jpg
# Segmentasi selesai: underripe (402).jpg -> segmented_underripe (402).jpg
# Segmentasi selesai: underripe (403).jpg -> segmented_underripe (403).jpg
# Segmentasi selesai: underripe (404).jpg -> segmented_underripe (404).jpg
# Segmentasi selesai: underripe (405).jpg -> segmented_underripe (405).jpg
# Segmentasi selesai: underripe (406).jpg -> segmented_underripe (406).jpg
# Segmentasi selesai: underripe (407).jpg -> segmented_underripe (407).jpg
# Segmentasi selesai: underripe (41).jpg -> segmented_underripe (41).jpg
# Segmentasi selesai: underripe (42).jpg -> segmented_underripe (42).jpg
# Segmentasi selesai: underripe (43).jpg -> segmented_underripe (43).jpg
# Segmentasi selesai: underripe (44).jpg -> segmented_underripe (44).jpg
# Segmentasi selesai: underripe (45).jpg -> segmented_underripe (45).jpg
# Segmentasi selesai: underripe (46).jpg -> segmented_underripe (46).jpg
# Segmentasi selesai: underripe (47).jpg -> segmented_underripe (47).jpg
# Segmentasi selesai: underripe (48).jpg -> segmented_underripe (48).jpg
# Segmentasi selesai: underripe (49).jpg -> segmented_underripe (49).jpg
# Segmentasi selesai: underripe (5).jpg -> segmented_underripe (5).jpg
# Segmentasi selesai: underripe (50).jpg -> segmented_underripe (50).jpg
# Segmentasi selesai: underripe (51).jpg -> segmented_underripe (51).jpg
# Segmentasi selesai: underripe (52).jpg -> segmented_underripe (52).jpg
# Segmentasi selesai: underripe (53).jpg -> segmented_underripe (53).jpg
# Segmentasi selesai: underripe (54).jpg -> segmented_underripe (54).jpg
# Segmentasi selesai: underripe (55).jpg -> segmented_underripe (55).jpg
# Segmentasi selesai: underripe (56).jpg -> segmented_underripe (56).jpg
# Segmentasi selesai: underripe (57).jpg -> segmented_underripe (57).jpg
# Segmentasi selesai: underripe (58).jpg -> segmented_underripe (58).jpg
# Segmentasi selesai: underripe (59).jpg -> segmented_underripe (59).jpg
# Segmentasi selesai: underripe (6).jpg -> segmented_underripe (6).jpg
# Segmentasi selesai: underripe (60).jpg -> segmented_underripe (60).jpg
# Segmentasi selesai: underripe (61).jpg -> segmented_underripe (61).jpg
# Segmentasi selesai: underripe (62).jpg -> segmented_underripe (62).jpg
# Segmentasi selesai: underripe (63).jpg -> segmented_underripe (63).jpg
# Segmentasi selesai: underripe (64).jpg -> segmented_underripe (64).jpg
# Segmentasi selesai: underripe (65).jpg -> segmented_underripe (65).jpg
# Segmentasi selesai: underripe (66).jpg -> segmented_underripe (66).jpg
# Segmentasi selesai: underripe (67).jpg -> segmented_underripe (67).jpg
# Segmentasi selesai: underripe (68).jpg -> segmented_underripe (68).jpg
# Segmentasi selesai: underripe (69).jpg -> segmented_underripe (69).jpg
# Segmentasi selesai: underripe (7).jpg -> segmented_underripe (7).jpg
# Segmentasi selesai: underripe (70).jpg -> segmented_underripe (70).jpg
# Segmentasi selesai: underripe (71).jpg -> segmented_underripe (71).jpg
# Segmentasi selesai: underripe (72).jpg -> segmented_underripe (72).jpg
# Segmentasi selesai: underripe (73).jpg -> segmented_underripe (73).jpg
# Segmentasi selesai: underripe (74).jpg -> segmented_underripe (74).jpg
# Segmentasi selesai: underripe (75).jpg -> segmented_underripe (75).jpg
# Segmentasi selesai: underripe (76).jpg -> segmented_underripe (76).jpg
# Segmentasi selesai: underripe (77).jpg -> segmented_underripe (77).jpg
# Segmentasi selesai: underripe (78).jpg -> segmented_underripe (78).jpg
# Segmentasi selesai: underripe (79).jpg -> segmented_underripe (79).jpg
# Segmentasi selesai: underripe (8).jpg -> segmented_underripe (8).jpg
# Segmentasi selesai: underripe (80).jpg -> segmented_underripe (80).jpg
# Segmentasi selesai: underripe (81).jpg -> segmented_underripe (81).jpg
# Segmentasi selesai: underripe (82).jpg -> segmented_underripe (82).jpg
# Segmentasi selesai: underripe (83).jpg -> segmented_underripe (83).jpg
# Segmentasi selesai: underripe (84).jpg -> segmented_underripe (84).jpg
# Segmentasi selesai: underripe (85).jpg -> segmented_underripe (85).jpg
# Segmentasi selesai: underripe (86).jpg -> segmented_underripe (86).jpg
# Segmentasi selesai: underripe (87).jpg -> segmented_underripe (87).jpg
# Segmentasi selesai: underripe (88).jpg -> segmented_underripe (88).jpg
# Segmentasi selesai: underripe (89).jpg -> segmented_underripe (89).jpg
# Segmentasi selesai: underripe (9).jpg -> segmented_underripe (9).jpg
# Segmentasi selesai: underripe (90).jpg -> segmented_underripe (90).jpg
# Segmentasi selesai: underripe (91).jpg -> segmented_underripe (91).jpg
# Segmentasi selesai: underripe (92).jpg -> segmented_underripe (92).jpg
# Segmentasi selesai: underripe (93).jpg -> segmented_underripe (93).jpg
# Segmentasi selesai: underripe (94).jpg -> segmented_underripe (94).jpg
# Segmentasi selesai: underripe (95).jpg -> segmented_underripe (95).jpg
# Segmentasi selesai: underripe (96).jpg -> segmented_underripe (96).jpg
# Segmentasi selesai: underripe (97).jpg -> segmented_underripe (97).jpg
# Segmentasi selesai: underripe (98).jpg -> segmented_underripe (98).jpg
# Segmentasi selesai: underripe (99).jpg -> segmented_underripe (99).jpg
# Segmentasi selesai: underripe.jpg -> segmented_underripe.jpg
