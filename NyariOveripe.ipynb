# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as gas

# %%
def nyaripisangoveripe(gambar):
    # Konversi gambar ke ruang warna HSV
    hsv = cv2.cvtColor(gambar, cv2.COLOR_BGR2HSV)

    # Definisikan rentang nilai warna kuning untuk segmentasi buah pisang
    lower_pisang = np.array([20, 100, 100])
    upper_pisang = np.array([30, 250, 255])

    # Buat mask berdasarkan rentang nilai warna kuning
    masked = cv2.inRange(hsv, lower_pisang, upper_pisang)
    
    # Menghitung jumlah piksel kuning dalam mask
    yellow_pixels = cv2.countNonZero(masked)
    
    # Mencari kontur dari mask
    contours, _ = cv2.findContours(masked, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    max_area = 0
    max_contour = None
    
    # Mencari kontur kuning dengan luas terbesar
    for contour in contours:
        area = cv2.contourArea(contour)
        
        if area > max_area:
            max_area = area
            max_contour = contour
    
    # Mengekstrak bounding box dari kontur terbesar
    x, y, w, h = cv2.boundingRect(max_contour)
    
    # Menambahkan margin pada bounding rectangle
    margin = 50
    x1 = max(0, x - margin)
    y1 = max(0, y - margin)
    x2 = min(gambar.shape[1], x + w + margin)
    y2 = min(gambar.shape[0], y + h + margin)
    
    # Menghitung koordinat tengah bounding box
    center_x = (x1 + x2) // 2
    center_y = (y1 + y2) // 2
    
    # Mengubah posisi kotak berdasarkan koordinat tengah bounding box
    kotak_width = 50
    kotak_height = 70
    kotak_x1 = max(0, center_x - kotak_width // 2)
    kotak_y1 = max(0, center_y - kotak_height // 2)
    kotak_x2 = min(gambar.shape[1], center_x + kotak_width // 2)
    kotak_y2 = min(gambar.shape[0], center_y + kotak_height // 2)
    
    # Membuat kotak 
    kotak = np.zeros((kotak_height, kotak_width, 3), dtype=np.uint8)
    kotak[:kotak_y2-kotak_y1, :kotak_x2-kotak_x1] = gambar[kotak_y1:kotak_y1+kotak_y2-kotak_y1, kotak_x1:kotak_x1+kotak_x2-kotak_x1]

    return kotak

# %%
def segmentasi_buah_pisang(input_dir, output_dir):
    # Buat direktori output jika belum ada
    os.makedirs(output_dir, exist_ok=True)

    # Dapatkan daftar file dalam direktori input
    file_list = os.listdir(input_dir)

    # Melakukan segmentasi pada setiap file gambar
    for file_name in file_list:
        # Baca gambar
        gambar = cv2.imread(os.path.join(input_dir, file_name))

        # Memeriksa jumlah piksel dengan metode segmentasi HSV
        segmented_img = nyaripisangoveripe(gambar)

        # Ubah nama file hasil segmentasi
        segmented_file_name = "segmented_" + file_name

        # Simpan hasil segmentasi ke direktori output
        cv2.imwrite(os.path.join(output_dir, segmented_file_name), segmented_img)

        print(f"Segmentasi selesai: {file_name} -> {segmented_file_name}")

# Contoh penggunaan
input_directory = "T:/PCD/Banana_Condensed_Three_Cat/overripe"
output_directory = "T:/PCD/Banana_Condensed_Three_Cat/segov"
segmentasi_buah_pisang(input_directory, output_directory)
# Out:
# Segmentasi selesai: overripe (10).jpg -> segmented_overripe (10).jpg
# Segmentasi selesai: overripe (100).jpg -> segmented_overripe (100).jpg
# Segmentasi selesai: overripe (101).jpg -> segmented_overripe (101).jpg
# Segmentasi selesai: overripe (102).jpg -> segmented_overripe (102).jpg
# Segmentasi selesai: overripe (103).jpg -> segmented_overripe (103).jpg
# Segmentasi selesai: overripe (104).jpg -> segmented_overripe (104).jpg
# Segmentasi selesai: overripe (105).jpg -> segmented_overripe (105).jpg
# Segmentasi selesai: overripe (106).jpg -> segmented_overripe (106).jpg
# Segmentasi selesai: overripe (107).jpg -> segmented_overripe (107).jpg
# Segmentasi selesai: overripe (108).jpg -> segmented_overripe (108).jpg
# Segmentasi selesai: overripe (109).jpg -> segmented_overripe (109).jpg
# Segmentasi selesai: overripe (11).jpg -> segmented_overripe (11).jpg
# Segmentasi selesai: overripe (110).jpg -> segmented_overripe (110).jpg
# Segmentasi selesai: overripe (111).jpg -> segmented_overripe (111).jpg
# Segmentasi selesai: overripe (112).jpg -> segmented_overripe (112).jpg
# Segmentasi selesai: overripe (113).jpg -> segmented_overripe (113).jpg
# Segmentasi selesai: overripe (114).jpg -> segmented_overripe (114).jpg
# Segmentasi selesai: overripe (115).jpg -> segmented_overripe (115).jpg
# Segmentasi selesai: overripe (116).jpg -> segmented_overripe (116).jpg
# Segmentasi selesai: overripe (117).jpg -> segmented_overripe (117).jpg
# Segmentasi selesai: overripe (118).jpg -> segmented_overripe (118).jpg
# Segmentasi selesai: overripe (119).jpg -> segmented_overripe (119).jpg
# Segmentasi selesai: overripe (12).jpg -> segmented_overripe (12).jpg
# Segmentasi selesai: overripe (120).jpg -> segmented_overripe (120).jpg
# Segmentasi selesai: overripe (121).jpg -> segmented_overripe (121).jpg
# Segmentasi selesai: overripe (122).jpg -> segmented_overripe (122).jpg
# Segmentasi selesai: overripe (123).jpg -> segmented_overripe (123).jpg
# Segmentasi selesai: overripe (124).jpg -> segmented_overripe (124).jpg
# Segmentasi selesai: overripe (125).jpg -> segmented_overripe (125).jpg
# Segmentasi selesai: overripe (126).jpg -> segmented_overripe (126).jpg
# Segmentasi selesai: overripe (127).jpg -> segmented_overripe (127).jpg
# Segmentasi selesai: overripe (128).jpg -> segmented_overripe (128).jpg
# Segmentasi selesai: overripe (129).jpg -> segmented_overripe (129).jpg
# Segmentasi selesai: overripe (13).jpg -> segmented_overripe (13).jpg
# Segmentasi selesai: overripe (130).jpg -> segmented_overripe (130).jpg
# Segmentasi selesai: overripe (131).jpg -> segmented_overripe (131).jpg
# Segmentasi selesai: overripe (132).jpg -> segmented_overripe (132).jpg
# Segmentasi selesai: overripe (133).jpg -> segmented_overripe (133).jpg
# Segmentasi selesai: overripe (134).jpg -> segmented_overripe (134).jpg
# Segmentasi selesai: overripe (135).jpg -> segmented_overripe (135).jpg
# Segmentasi selesai: overripe (136).jpg -> segmented_overripe (136).jpg
# Segmentasi selesai: overripe (137).jpg -> segmented_overripe (137).jpg
# Segmentasi selesai: overripe (138).jpg -> segmented_overripe (138).jpg
# Segmentasi selesai: overripe (139).jpg -> segmented_overripe (139).jpg
# Segmentasi selesai: overripe (14).jpg -> segmented_overripe (14).jpg
# Segmentasi selesai: overripe (140).jpg -> segmented_overripe (140).jpg
# Segmentasi selesai: overripe (141).jpg -> segmented_overripe (141).jpg
# Segmentasi selesai: overripe (142).jpg -> segmented_overripe (142).jpg
# Segmentasi selesai: overripe (143).jpg -> segmented_overripe (143).jpg
# Segmentasi selesai: overripe (144).jpg -> segmented_overripe (144).jpg
# Segmentasi selesai: overripe (145).jpg -> segmented_overripe (145).jpg
# Segmentasi selesai: overripe (146).jpg -> segmented_overripe (146).jpg
# Segmentasi selesai: overripe (147).jpg -> segmented_overripe (147).jpg
# Segmentasi selesai: overripe (148).jpg -> segmented_overripe (148).jpg
# Segmentasi selesai: overripe (149).jpg -> segmented_overripe (149).jpg
# Segmentasi selesai: overripe (15).jpg -> segmented_overripe (15).jpg
# Segmentasi selesai: overripe (150).jpg -> segmented_overripe (150).jpg
# Segmentasi selesai: overripe (151).jpg -> segmented_overripe (151).jpg
# Segmentasi selesai: overripe (152).jpg -> segmented_overripe (152).jpg
# Segmentasi selesai: overripe (153).jpg -> segmented_overripe (153).jpg
# Segmentasi selesai: overripe (154).jpg -> segmented_overripe (154).jpg
# Segmentasi selesai: overripe (155).jpg -> segmented_overripe (155).jpg
# Segmentasi selesai: overripe (156).jpg -> segmented_overripe (156).jpg
# Segmentasi selesai: overripe (157).jpg -> segmented_overripe (157).jpg
# Segmentasi selesai: overripe (158).jpg -> segmented_overripe (158).jpg
# Segmentasi selesai: overripe (159).jpg -> segmented_overripe (159).jpg
# Segmentasi selesai: overripe (16).jpg -> segmented_overripe (16).jpg
# Segmentasi selesai: overripe (160).jpg -> segmented_overripe (160).jpg
# Segmentasi selesai: overripe (161).jpg -> segmented_overripe (161).jpg
# Segmentasi selesai: overripe (162).jpg -> segmented_overripe (162).jpg
# Segmentasi selesai: overripe (163).jpg -> segmented_overripe (163).jpg
# Segmentasi selesai: overripe (164).jpg -> segmented_overripe (164).jpg
# Segmentasi selesai: overripe (165).jpg -> segmented_overripe (165).jpg
# Segmentasi selesai: overripe (166).jpg -> segmented_overripe (166).jpg
# Segmentasi selesai: overripe (167).jpg -> segmented_overripe (167).jpg
# Segmentasi selesai: overripe (168).jpg -> segmented_overripe (168).jpg
# Segmentasi selesai: overripe (169).jpg -> segmented_overripe (169).jpg
# Segmentasi selesai: overripe (17).jpg -> segmented_overripe (17).jpg
# Segmentasi selesai: overripe (170).jpg -> segmented_overripe (170).jpg
# Segmentasi selesai: overripe (171).jpg -> segmented_overripe (171).jpg
# Segmentasi selesai: overripe (172).jpg -> segmented_overripe (172).jpg
# Segmentasi selesai: overripe (173).jpg -> segmented_overripe (173).jpg
# Segmentasi selesai: overripe (174).jpg -> segmented_overripe (174).jpg
# Segmentasi selesai: overripe (175).jpg -> segmented_overripe (175).jpg
# Segmentasi selesai: overripe (176).jpg -> segmented_overripe (176).jpg
# Segmentasi selesai: overripe (177).jpg -> segmented_overripe (177).jpg
# Segmentasi selesai: overripe (178).jpg -> segmented_overripe (178).jpg
# Segmentasi selesai: overripe (179).jpg -> segmented_overripe (179).jpg
# Segmentasi selesai: overripe (18).jpg -> segmented_overripe (18).jpg
# Segmentasi selesai: overripe (180).jpg -> segmented_overripe (180).jpg
# Segmentasi selesai: overripe (181).jpg -> segmented_overripe (181).jpg
# Segmentasi selesai: overripe (182).jpg -> segmented_overripe (182).jpg
# Segmentasi selesai: overripe (183).jpg -> segmented_overripe (183).jpg
# Segmentasi selesai: overripe (184).jpg -> segmented_overripe (184).jpg
# Segmentasi selesai: overripe (185).jpg -> segmented_overripe (185).jpg
# Segmentasi selesai: overripe (186).jpg -> segmented_overripe (186).jpg
# Segmentasi selesai: overripe (187).jpg -> segmented_overripe (187).jpg
# Segmentasi selesai: overripe (188).jpg -> segmented_overripe (188).jpg
# Segmentasi selesai: overripe (189).jpg -> segmented_overripe (189).jpg
# Segmentasi selesai: overripe (19).jpg -> segmented_overripe (19).jpg
# Segmentasi selesai: overripe (190).jpg -> segmented_overripe (190).jpg
# Segmentasi selesai: overripe (191).jpg -> segmented_overripe (191).jpg
# Segmentasi selesai: overripe (192).jpg -> segmented_overripe (192).jpg
# Segmentasi selesai: overripe (193).jpg -> segmented_overripe (193).jpg
# Segmentasi selesai: overripe (194).jpg -> segmented_overripe (194).jpg
# Segmentasi selesai: overripe (195).jpg -> segmented_overripe (195).jpg
# Segmentasi selesai: overripe (196).jpg -> segmented_overripe (196).jpg
# Segmentasi selesai: overripe (197).jpg -> segmented_overripe (197).jpg
# Segmentasi selesai: overripe (198).jpg -> segmented_overripe (198).jpg
# Segmentasi selesai: overripe (199).jpg -> segmented_overripe (199).jpg
# Segmentasi selesai: overripe (2).jpg -> segmented_overripe (2).jpg
# Segmentasi selesai: overripe (20).jpg -> segmented_overripe (20).jpg
# Segmentasi selesai: overripe (200).jpg -> segmented_overripe (200).jpg
# Segmentasi selesai: overripe (201).jpg -> segmented_overripe (201).jpg
# Segmentasi selesai: overripe (202).jpg -> segmented_overripe (202).jpg
# Segmentasi selesai: overripe (203).jpg -> segmented_overripe (203).jpg
# Segmentasi selesai: overripe (204).jpg -> segmented_overripe (204).jpg
# Segmentasi selesai: overripe (205).jpg -> segmented_overripe (205).jpg
# Segmentasi selesai: overripe (206).jpg -> segmented_overripe (206).jpg
# Segmentasi selesai: overripe (207).jpg -> segmented_overripe (207).jpg
# Segmentasi selesai: overripe (208).jpg -> segmented_overripe (208).jpg
# Segmentasi selesai: overripe (209).jpg -> segmented_overripe (209).jpg
# Segmentasi selesai: overripe (21).jpg -> segmented_overripe (21).jpg
# Segmentasi selesai: overripe (210).jpg -> segmented_overripe (210).jpg
# Segmentasi selesai: overripe (211).jpg -> segmented_overripe (211).jpg
# Segmentasi selesai: overripe (212).jpg -> segmented_overripe (212).jpg
# Segmentasi selesai: overripe (213).jpg -> segmented_overripe (213).jpg
# Segmentasi selesai: overripe (214).jpg -> segmented_overripe (214).jpg
# Segmentasi selesai: overripe (215).jpg -> segmented_overripe (215).jpg
# Segmentasi selesai: overripe (216).jpg -> segmented_overripe (216).jpg
# Segmentasi selesai: overripe (217).jpg -> segmented_overripe (217).jpg
# Segmentasi selesai: overripe (218).jpg -> segmented_overripe (218).jpg
# Segmentasi selesai: overripe (219).jpg -> segmented_overripe (219).jpg
# Segmentasi selesai: overripe (22).jpg -> segmented_overripe (22).jpg
# Segmentasi selesai: overripe (220).jpg -> segmented_overripe (220).jpg
# Segmentasi selesai: overripe (221).jpg -> segmented_overripe (221).jpg
# Segmentasi selesai: overripe (222).jpg -> segmented_overripe (222).jpg
# Segmentasi selesai: overripe (223).jpg -> segmented_overripe (223).jpg
# Segmentasi selesai: overripe (224).jpg -> segmented_overripe (224).jpg
# Segmentasi selesai: overripe (225).jpg -> segmented_overripe (225).jpg
# Segmentasi selesai: overripe (226).jpg -> segmented_overripe (226).jpg
# Segmentasi selesai: overripe (227).jpg -> segmented_overripe (227).jpg
# Segmentasi selesai: overripe (228).jpg -> segmented_overripe (228).jpg
# Segmentasi selesai: overripe (229).jpg -> segmented_overripe (229).jpg
# Segmentasi selesai: overripe (23).jpg -> segmented_overripe (23).jpg
# Segmentasi selesai: overripe (230).jpg -> segmented_overripe (230).jpg
# Segmentasi selesai: overripe (231).jpg -> segmented_overripe (231).jpg
# Segmentasi selesai: overripe (232).jpg -> segmented_overripe (232).jpg
# Segmentasi selesai: overripe (233).jpg -> segmented_overripe (233).jpg
# Segmentasi selesai: overripe (234).jpg -> segmented_overripe (234).jpg
# Segmentasi selesai: overripe (235).jpg -> segmented_overripe (235).jpg
# Segmentasi selesai: overripe (236).jpg -> segmented_overripe (236).jpg
# Segmentasi selesai: overripe (237).jpg -> segmented_overripe (237).jpg
# Segmentasi selesai: overripe (238).jpg -> segmented_overripe (238).jpg
# Segmentasi selesai: overripe (239).jpg -> segmented_overripe (239).jpg
# Segmentasi selesai: overripe (24).jpg -> segmented_overripe (24).jpg
# Segmentasi selesai: overripe (240).jpg -> segmented_overripe (240).jpg
# Segmentasi selesai: overripe (241).jpg -> segmented_overripe (241).jpg
# Segmentasi selesai: overripe (242).jpg -> segmented_overripe (242).jpg
# Segmentasi selesai: overripe (243).jpg -> segmented_overripe (243).jpg
# Segmentasi selesai: overripe (244).jpg -> segmented_overripe (244).jpg
# Segmentasi selesai: overripe (245).jpg -> segmented_overripe (245).jpg
# Segmentasi selesai: overripe (246).jpg -> segmented_overripe (246).jpg
# Segmentasi selesai: overripe (247).jpg -> segmented_overripe (247).jpg
# Segmentasi selesai: overripe (248).jpg -> segmented_overripe (248).jpg
# Segmentasi selesai: overripe (249).jpg -> segmented_overripe (249).jpg
# Segmentasi selesai: overripe (25).jpg -> segmented_overripe (25).jpg
# Segmentasi selesai: overripe (250).jpg -> segmented_overripe (250).jpg
# Segmentasi selesai: overripe (251).jpg -> segmented_overripe (251).jpg
# Segmentasi selesai: overripe (252).jpg -> segmented_overripe (252).jpg
# Segmentasi selesai: overripe (253).jpg -> segmented_overripe (253).jpg
# Segmentasi selesai: overripe (254).jpg -> segmented_overripe (254).jpg
# Segmentasi selesai: overripe (255).jpg -> segmented_overripe (255).jpg
# Segmentasi selesai: overripe (256).jpg -> segmented_overripe (256).jpg
# Segmentasi selesai: overripe (257).jpg -> segmented_overripe (257).jpg
# Segmentasi selesai: overripe (258).jpg -> segmented_overripe (258).jpg
# Segmentasi selesai: overripe (259).jpg -> segmented_overripe (259).jpg
# Segmentasi selesai: overripe (26).jpg -> segmented_overripe (26).jpg
# Segmentasi selesai: overripe (260).jpg -> segmented_overripe (260).jpg
# Segmentasi selesai: overripe (261).jpg -> segmented_overripe (261).jpg
# Segmentasi selesai: overripe (262).jpg -> segmented_overripe (262).jpg
# Segmentasi selesai: overripe (263).jpg -> segmented_overripe (263).jpg
# Segmentasi selesai: overripe (264).jpg -> segmented_overripe (264).jpg
# Segmentasi selesai: overripe (265).jpg -> segmented_overripe (265).jpg
# Segmentasi selesai: overripe (266).jpg -> segmented_overripe (266).jpg
# Segmentasi selesai: overripe (267).jpg -> segmented_overripe (267).jpg
# Segmentasi selesai: overripe (268).jpg -> segmented_overripe (268).jpg
# Segmentasi selesai: overripe (269).jpg -> segmented_overripe (269).jpg
# Segmentasi selesai: overripe (27).jpg -> segmented_overripe (27).jpg
# Segmentasi selesai: overripe (270).jpg -> segmented_overripe (270).jpg
# Segmentasi selesai: overripe (271).jpg -> segmented_overripe (271).jpg
# Segmentasi selesai: overripe (272).jpg -> segmented_overripe (272).jpg
# Segmentasi selesai: overripe (273).jpg -> segmented_overripe (273).jpg
# Segmentasi selesai: overripe (274).jpg -> segmented_overripe (274).jpg
# Segmentasi selesai: overripe (275).jpg -> segmented_overripe (275).jpg
# Segmentasi selesai: overripe (276).jpg -> segmented_overripe (276).jpg
# Segmentasi selesai: overripe (277).jpg -> segmented_overripe (277).jpg
# Segmentasi selesai: overripe (278).jpg -> segmented_overripe (278).jpg
# Segmentasi selesai: overripe (279).jpg -> segmented_overripe (279).jpg
# Segmentasi selesai: overripe (28).jpg -> segmented_overripe (28).jpg
# Segmentasi selesai: overripe (280).jpg -> segmented_overripe (280).jpg
# Segmentasi selesai: overripe (281).jpg -> segmented_overripe (281).jpg
# Segmentasi selesai: overripe (282).jpg -> segmented_overripe (282).jpg
# Segmentasi selesai: overripe (283).jpg -> segmented_overripe (283).jpg
# Segmentasi selesai: overripe (284).jpg -> segmented_overripe (284).jpg
# Segmentasi selesai: overripe (285).jpg -> segmented_overripe (285).jpg
# Segmentasi selesai: overripe (286).jpg -> segmented_overripe (286).jpg
# Segmentasi selesai: overripe (287).jpg -> segmented_overripe (287).jpg
# Segmentasi selesai: overripe (288).jpg -> segmented_overripe (288).jpg
# Segmentasi selesai: overripe (289).jpg -> segmented_overripe (289).jpg
# Segmentasi selesai: overripe (29).jpg -> segmented_overripe (29).jpg
# Segmentasi selesai: overripe (290).jpg -> segmented_overripe (290).jpg
# Segmentasi selesai: overripe (291).jpg -> segmented_overripe (291).jpg
# Segmentasi selesai: overripe (292).jpg -> segmented_overripe (292).jpg
# Segmentasi selesai: overripe (293).jpg -> segmented_overripe (293).jpg
# Segmentasi selesai: overripe (294).jpg -> segmented_overripe (294).jpg
# Segmentasi selesai: overripe (295).jpg -> segmented_overripe (295).jpg
# Segmentasi selesai: overripe (296).jpg -> segmented_overripe (296).jpg
# Segmentasi selesai: overripe (297).jpg -> segmented_overripe (297).jpg
# Segmentasi selesai: overripe (298).jpg -> segmented_overripe (298).jpg
# Segmentasi selesai: overripe (299).jpg -> segmented_overripe (299).jpg
# Segmentasi selesai: overripe (3).jpg -> segmented_overripe (3).jpg
# Segmentasi selesai: overripe (30).jpg -> segmented_overripe (30).jpg
# Segmentasi selesai: overripe (300).jpg -> segmented_overripe (300).jpg
# Segmentasi selesai: overripe (301).jpg -> segmented_overripe (301).jpg
# Segmentasi selesai: overripe (302).jpg -> segmented_overripe (302).jpg
# Segmentasi selesai: overripe (303).jpg -> segmented_overripe (303).jpg
# Segmentasi selesai: overripe (304).jpg -> segmented_overripe (304).jpg
# Segmentasi selesai: overripe (305).jpg -> segmented_overripe (305).jpg
# Segmentasi selesai: overripe (306).jpg -> segmented_overripe (306).jpg
# Segmentasi selesai: overripe (307).jpg -> segmented_overripe (307).jpg
# Segmentasi selesai: overripe (308).jpg -> segmented_overripe (308).jpg
# Segmentasi selesai: overripe (309).jpg -> segmented_overripe (309).jpg
# Segmentasi selesai: overripe (31).jpg -> segmented_overripe (31).jpg
# Segmentasi selesai: overripe (310).jpg -> segmented_overripe (310).jpg
# Segmentasi selesai: overripe (311).jpg -> segmented_overripe (311).jpg
# Segmentasi selesai: overripe (312).jpg -> segmented_overripe (312).jpg
# Segmentasi selesai: overripe (313).jpg -> segmented_overripe (313).jpg
# Segmentasi selesai: overripe (314).jpg -> segmented_overripe (314).jpg
# Segmentasi selesai: overripe (315).jpg -> segmented_overripe (315).jpg
# Segmentasi selesai: overripe (316).jpg -> segmented_overripe (316).jpg
# Segmentasi selesai: overripe (317).jpg -> segmented_overripe (317).jpg
# Segmentasi selesai: overripe (318).jpg -> segmented_overripe (318).jpg
# Segmentasi selesai: overripe (319).jpg -> segmented_overripe (319).jpg
# Segmentasi selesai: overripe (32).jpg -> segmented_overripe (32).jpg
# Segmentasi selesai: overripe (320).jpg -> segmented_overripe (320).jpg
# Segmentasi selesai: overripe (321).jpg -> segmented_overripe (321).jpg
# Segmentasi selesai: overripe (322).jpg -> segmented_overripe (322).jpg
# Segmentasi selesai: overripe (323).jpg -> segmented_overripe (323).jpg
# Segmentasi selesai: overripe (324).jpg -> segmented_overripe (324).jpg
# Segmentasi selesai: overripe (325).jpg -> segmented_overripe (325).jpg
# Segmentasi selesai: overripe (326).jpg -> segmented_overripe (326).jpg
# Segmentasi selesai: overripe (327).jpg -> segmented_overripe (327).jpg
# Segmentasi selesai: overripe (328).jpg -> segmented_overripe (328).jpg
# Segmentasi selesai: overripe (329).jpg -> segmented_overripe (329).jpg
# Segmentasi selesai: overripe (33).jpg -> segmented_overripe (33).jpg
# Segmentasi selesai: overripe (330).jpg -> segmented_overripe (330).jpg
# Segmentasi selesai: overripe (331).jpg -> segmented_overripe (331).jpg
# Segmentasi selesai: overripe (332).jpg -> segmented_overripe (332).jpg
# Segmentasi selesai: overripe (333).jpg -> segmented_overripe (333).jpg
# Segmentasi selesai: overripe (334).jpg -> segmented_overripe (334).jpg
# Segmentasi selesai: overripe (335).jpg -> segmented_overripe (335).jpg
# Segmentasi selesai: overripe (336).jpg -> segmented_overripe (336).jpg
# Segmentasi selesai: overripe (337).jpg -> segmented_overripe (337).jpg
# Segmentasi selesai: overripe (338).jpg -> segmented_overripe (338).jpg
# Segmentasi selesai: overripe (339).jpg -> segmented_overripe (339).jpg
# Segmentasi selesai: overripe (34).jpg -> segmented_overripe (34).jpg
# Segmentasi selesai: overripe (340).jpg -> segmented_overripe (340).jpg
# Segmentasi selesai: overripe (341).jpg -> segmented_overripe (341).jpg
# Segmentasi selesai: overripe (342).jpg -> segmented_overripe (342).jpg
# Segmentasi selesai: overripe (343).jpg -> segmented_overripe (343).jpg
# Segmentasi selesai: overripe (344).jpg -> segmented_overripe (344).jpg
# Segmentasi selesai: overripe (345).jpg -> segmented_overripe (345).jpg
# Segmentasi selesai: overripe (346).jpg -> segmented_overripe (346).jpg
# Segmentasi selesai: overripe (347).jpg -> segmented_overripe (347).jpg
# Segmentasi selesai: overripe (348).jpg -> segmented_overripe (348).jpg
# Segmentasi selesai: overripe (349).jpg -> segmented_overripe (349).jpg
# Segmentasi selesai: overripe (35).jpg -> segmented_overripe (35).jpg
# Segmentasi selesai: overripe (350).jpg -> segmented_overripe (350).jpg
# Segmentasi selesai: overripe (351).jpg -> segmented_overripe (351).jpg
# Segmentasi selesai: overripe (352).jpg -> segmented_overripe (352).jpg
# Segmentasi selesai: overripe (353).jpg -> segmented_overripe (353).jpg
# Segmentasi selesai: overripe (354).jpg -> segmented_overripe (354).jpg
# Segmentasi selesai: overripe (355).jpg -> segmented_overripe (355).jpg
# Segmentasi selesai: overripe (356).jpg -> segmented_overripe (356).jpg
# Segmentasi selesai: overripe (357).jpg -> segmented_overripe (357).jpg
# Segmentasi selesai: overripe (358).jpg -> segmented_overripe (358).jpg
# Segmentasi selesai: overripe (359).jpg -> segmented_overripe (359).jpg
# Segmentasi selesai: overripe (36).jpg -> segmented_overripe (36).jpg
# Segmentasi selesai: overripe (360).jpg -> segmented_overripe (360).jpg
# Segmentasi selesai: overripe (361).jpg -> segmented_overripe (361).jpg
# Segmentasi selesai: overripe (362).jpg -> segmented_overripe (362).jpg
# Segmentasi selesai: overripe (363).jpg -> segmented_overripe (363).jpg
# Segmentasi selesai: overripe (364).jpg -> segmented_overripe (364).jpg
# Segmentasi selesai: overripe (365).jpg -> segmented_overripe (365).jpg
# Segmentasi selesai: overripe (366).jpg -> segmented_overripe (366).jpg
# Segmentasi selesai: overripe (367).jpg -> segmented_overripe (367).jpg
# Segmentasi selesai: overripe (368).jpg -> segmented_overripe (368).jpg
# Segmentasi selesai: overripe (369).jpg -> segmented_overripe (369).jpg
# Segmentasi selesai: overripe (37).jpg -> segmented_overripe (37).jpg
# Segmentasi selesai: overripe (370).jpg -> segmented_overripe (370).jpg
# Segmentasi selesai: overripe (371).jpg -> segmented_overripe (371).jpg
# Segmentasi selesai: overripe (372).jpg -> segmented_overripe (372).jpg
# Segmentasi selesai: overripe (373).jpg -> segmented_overripe (373).jpg
# Segmentasi selesai: overripe (374).jpg -> segmented_overripe (374).jpg
# Segmentasi selesai: overripe (375).jpg -> segmented_overripe (375).jpg
# Segmentasi selesai: overripe (376).jpg -> segmented_overripe (376).jpg
# Segmentasi selesai: overripe (377).jpg -> segmented_overripe (377).jpg
# Segmentasi selesai: overripe (378).jpg -> segmented_overripe (378).jpg
# Segmentasi selesai: overripe (379).jpg -> segmented_overripe (379).jpg
# Segmentasi selesai: overripe (38).jpg -> segmented_overripe (38).jpg
# Segmentasi selesai: overripe (380).jpg -> segmented_overripe (380).jpg
# Segmentasi selesai: overripe (381).jpg -> segmented_overripe (381).jpg
# Segmentasi selesai: overripe (382).jpg -> segmented_overripe (382).jpg
# Segmentasi selesai: overripe (383).jpg -> segmented_overripe (383).jpg
# Segmentasi selesai: overripe (384).jpg -> segmented_overripe (384).jpg
# Segmentasi selesai: overripe (385).jpg -> segmented_overripe (385).jpg
# Segmentasi selesai: overripe (386).jpg -> segmented_overripe (386).jpg
# Segmentasi selesai: overripe (387).jpg -> segmented_overripe (387).jpg
# Segmentasi selesai: overripe (388).jpg -> segmented_overripe (388).jpg
# Segmentasi selesai: overripe (389).jpg -> segmented_overripe (389).jpg
# Segmentasi selesai: overripe (39).jpg -> segmented_overripe (39).jpg
# Segmentasi selesai: overripe (390).jpg -> segmented_overripe (390).jpg
# Segmentasi selesai: overripe (391).jpg -> segmented_overripe (391).jpg
# Segmentasi selesai: overripe (392).jpg -> segmented_overripe (392).jpg
# Segmentasi selesai: overripe (393).jpg -> segmented_overripe (393).jpg
# Segmentasi selesai: overripe (394).jpg -> segmented_overripe (394).jpg
# Segmentasi selesai: overripe (395).jpg -> segmented_overripe (395).jpg
# Segmentasi selesai: overripe (396).jpg -> segmented_overripe (396).jpg
# Segmentasi selesai: overripe (397).jpg -> segmented_overripe (397).jpg
# Segmentasi selesai: overripe (398).jpg -> segmented_overripe (398).jpg
# Segmentasi selesai: overripe (399).jpg -> segmented_overripe (399).jpg
# Segmentasi selesai: overripe (4).jpg -> segmented_overripe (4).jpg
# Segmentasi selesai: overripe (40).jpg -> segmented_overripe (40).jpg
# Segmentasi selesai: overripe (400).jpg -> segmented_overripe (400).jpg
# Segmentasi selesai: overripe (401).jpg -> segmented_overripe (401).jpg
# Segmentasi selesai: overripe (402).jpg -> segmented_overripe (402).jpg
# Segmentasi selesai: overripe (403).jpg -> segmented_overripe (403).jpg
# Segmentasi selesai: overripe (404).jpg -> segmented_overripe (404).jpg
# Segmentasi selesai: overripe (405).jpg -> segmented_overripe (405).jpg
# Segmentasi selesai: overripe (406).jpg -> segmented_overripe (406).jpg
# Segmentasi selesai: overripe (407).jpg -> segmented_overripe (407).jpg
# Segmentasi selesai: overripe (408).jpg -> segmented_overripe (408).jpg
# Segmentasi selesai: overripe (409).jpg -> segmented_overripe (409).jpg
# Segmentasi selesai: overripe (41).jpg -> segmented_overripe (41).jpg
# Segmentasi selesai: overripe (410).jpg -> segmented_overripe (410).jpg
# Segmentasi selesai: overripe (411).jpg -> segmented_overripe (411).jpg
# Segmentasi selesai: overripe (412).jpg -> segmented_overripe (412).jpg
# Segmentasi selesai: overripe (413).jpg -> segmented_overripe (413).jpg
# Segmentasi selesai: overripe (414).jpg -> segmented_overripe (414).jpg
# Segmentasi selesai: overripe (415).jpg -> segmented_overripe (415).jpg
# Segmentasi selesai: overripe (416).jpg -> segmented_overripe (416).jpg
# Segmentasi selesai: overripe (417).jpg -> segmented_overripe (417).jpg
# Segmentasi selesai: overripe (418).jpg -> segmented_overripe (418).jpg
# Segmentasi selesai: overripe (419).jpg -> segmented_overripe (419).jpg
# Segmentasi selesai: overripe (42).jpg -> segmented_overripe (42).jpg
# Segmentasi selesai: overripe (420).jpg -> segmented_overripe (420).jpg
# Segmentasi selesai: overripe (421).jpg -> segmented_overripe (421).jpg
# Segmentasi selesai: overripe (422).jpg -> segmented_overripe (422).jpg
# Segmentasi selesai: overripe (423).jpg -> segmented_overripe (423).jpg
# Segmentasi selesai: overripe (424).jpg -> segmented_overripe (424).jpg
# Segmentasi selesai: overripe (425).jpg -> segmented_overripe (425).jpg
# Segmentasi selesai: overripe (426).jpg -> segmented_overripe (426).jpg
# Segmentasi selesai: overripe (427).jpg -> segmented_overripe (427).jpg
# Segmentasi selesai: overripe (428).jpg -> segmented_overripe (428).jpg
# Segmentasi selesai: overripe (429).jpg -> segmented_overripe (429).jpg
# Segmentasi selesai: overripe (43).jpg -> segmented_overripe (43).jpg
# Segmentasi selesai: overripe (430).jpg -> segmented_overripe (430).jpg
# Segmentasi selesai: overripe (44).jpg -> segmented_overripe (44).jpg
# Segmentasi selesai: overripe (45).jpg -> segmented_overripe (45).jpg
# Segmentasi selesai: overripe (46).jpg -> segmented_overripe (46).jpg
# Segmentasi selesai: overripe (47).jpg -> segmented_overripe (47).jpg
# Segmentasi selesai: overripe (48).jpg -> segmented_overripe (48).jpg
# Segmentasi selesai: overripe (49).jpg -> segmented_overripe (49).jpg
# Segmentasi selesai: overripe (5).jpg -> segmented_overripe (5).jpg
# Segmentasi selesai: overripe (50).jpg -> segmented_overripe (50).jpg
# Segmentasi selesai: overripe (51).jpg -> segmented_overripe (51).jpg
# Segmentasi selesai: overripe (52).jpg -> segmented_overripe (52).jpg
# Segmentasi selesai: overripe (53).jpg -> segmented_overripe (53).jpg
# Segmentasi selesai: overripe (54).jpg -> segmented_overripe (54).jpg
# Segmentasi selesai: overripe (55).jpg -> segmented_overripe (55).jpg
# Segmentasi selesai: overripe (56).jpg -> segmented_overripe (56).jpg
# Segmentasi selesai: overripe (57).jpg -> segmented_overripe (57).jpg
# Segmentasi selesai: overripe (58).jpg -> segmented_overripe (58).jpg
# Segmentasi selesai: overripe (59).jpg -> segmented_overripe (59).jpg
# Segmentasi selesai: overripe (6).jpg -> segmented_overripe (6).jpg
# Segmentasi selesai: overripe (60).jpg -> segmented_overripe (60).jpg
# Segmentasi selesai: overripe (61).jpg -> segmented_overripe (61).jpg
# Segmentasi selesai: overripe (62).jpg -> segmented_overripe (62).jpg
# Segmentasi selesai: overripe (63).jpg -> segmented_overripe (63).jpg
# Segmentasi selesai: overripe (64).jpg -> segmented_overripe (64).jpg
# Segmentasi selesai: overripe (65).jpg -> segmented_overripe (65).jpg
# Segmentasi selesai: overripe (66).jpg -> segmented_overripe (66).jpg
# Segmentasi selesai: overripe (67).jpg -> segmented_overripe (67).jpg
# Segmentasi selesai: overripe (68).jpg -> segmented_overripe (68).jpg
# Segmentasi selesai: overripe (69).jpg -> segmented_overripe (69).jpg
# Segmentasi selesai: overripe (7).jpg -> segmented_overripe (7).jpg
# Segmentasi selesai: overripe (70).jpg -> segmented_overripe (70).jpg
# Segmentasi selesai: overripe (71).jpg -> segmented_overripe (71).jpg
# Segmentasi selesai: overripe (72).jpg -> segmented_overripe (72).jpg
# Segmentasi selesai: overripe (73).jpg -> segmented_overripe (73).jpg
# Segmentasi selesai: overripe (74).jpg -> segmented_overripe (74).jpg
# Segmentasi selesai: overripe (75).jpg -> segmented_overripe (75).jpg
# Segmentasi selesai: overripe (76).jpg -> segmented_overripe (76).jpg
# Segmentasi selesai: overripe (77).jpg -> segmented_overripe (77).jpg
# Segmentasi selesai: overripe (78).jpg -> segmented_overripe (78).jpg
# Segmentasi selesai: overripe (79).jpg -> segmented_overripe (79).jpg
# Segmentasi selesai: overripe (8).jpg -> segmented_overripe (8).jpg
# Segmentasi selesai: overripe (80).jpg -> segmented_overripe (80).jpg
# Segmentasi selesai: overripe (81).jpg -> segmented_overripe (81).jpg
# Segmentasi selesai: overripe (82).jpg -> segmented_overripe (82).jpg
# Segmentasi selesai: overripe (83).jpg -> segmented_overripe (83).jpg
# Segmentasi selesai: overripe (84).jpg -> segmented_overripe (84).jpg
# Segmentasi selesai: overripe (85).jpg -> segmented_overripe (85).jpg
# Segmentasi selesai: overripe (86).jpg -> segmented_overripe (86).jpg
# Segmentasi selesai: overripe (87).jpg -> segmented_overripe (87).jpg
# Segmentasi selesai: overripe (88).jpg -> segmented_overripe (88).jpg
# Segmentasi selesai: overripe (89).jpg -> segmented_overripe (89).jpg
# Segmentasi selesai: overripe (9).jpg -> segmented_overripe (9).jpg
# Segmentasi selesai: overripe (90).jpg -> segmented_overripe (90).jpg
# Segmentasi selesai: overripe (91).jpg -> segmented_overripe (91).jpg
# Segmentasi selesai: overripe (92).jpg -> segmented_overripe (92).jpg
# Segmentasi selesai: overripe (93).jpg -> segmented_overripe (93).jpg
# Segmentasi selesai: overripe (94).jpg -> segmented_overripe (94).jpg
# Segmentasi selesai: overripe (95).jpg -> segmented_overripe (95).jpg
# Segmentasi selesai: overripe (96).jpg -> segmented_overripe (96).jpg
# Segmentasi selesai: overripe (97).jpg -> segmented_overripe (97).jpg
# Segmentasi selesai: overripe (98).jpg -> segmented_overripe (98).jpg
# Segmentasi selesai: overripe (99).jpg -> segmented_overripe (99).jpg
# Segmentasi selesai: overripe.jpg -> segmented_overripe.jpg
# Segmentasi selesai: overripe_2 (2).jpg -> segmented_overripe_2 (2).jpg
# Segmentasi selesai: overripe_2 (3).jpg -> segmented_overripe_2 (3).jpg
# Segmentasi selesai: overripe_2 (4).jpg -> segmented_overripe_2 (4).jpg
# Segmentasi selesai: overripe_2 (5).jpg -> segmented_overripe_2 (5).jpg
# Segmentasi selesai: overripe_2.jpg -> segmented_overripe_2.jpg
