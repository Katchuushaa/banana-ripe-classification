# %%
#import library atau packages
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
#import png dan baca 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mateng = cv2.imread("/content/drive/MyDrive/PCD/Pepe Cede/ripe (2).jpg",0)
overmateng = cv2.imread("/content/drive/MyDrive/PCD/Pepe Cede/overripe (3).jpg",0)
undermateng = cv2.imread("/content/drive/MyDrive/PCD/Pepe Cede/underripe (10).jpg")

# %%
cv2_imshow(mateng)
# Out:
# <PIL.Image.Image image mode=L size=288x384 at 0x7FA7CFD6FEE0>

# %%
cv2_imshow(overmateng)
# Out:
# <PIL.Image.Image image mode=L size=288x384 at 0x7FA7CF16AF20>

# %%
cv2_imshow(undermateng)
# Out:
# <PIL.Image.Image image mode=RGB size=288x384 at 0x7FA7CF16AC20>

# %%
row, col, ch = undermateng.shape 
kanvas_hsv = np.zeros((row, col, 3), np.uint8)
undermatengHSV = cv2.cvtColor(undermateng, cv2.COLOR_RGB2HSV)

# %%
#splitting
h,s,v = cv2.split(undermatengHSV)
#Preview HSV setelah di splitting
cv2_imshow(h)
cv2_imshow(s)
cv2_imshow(v)
# Out:
# <PIL.Image.Image image mode=L size=288x384 at 0x7FA7CF16BD60>
# <PIL.Image.Image image mode=L size=288x384 at 0x7FA7CF16AAD0>
# <PIL.Image.Image image mode=L size=288x384 at 0x7FA7CFD6FA00>
