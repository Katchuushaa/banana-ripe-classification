# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as gas

# %%
def nyaripisangripe(gambar):
    # Konversi gambar ke ruang warna HSV
    hsv = cv2.cvtColor(gambar, cv2.COLOR_BGR2HSV)

    # Definisikan rentang nilai warna kuning untuk segmentasi buah pisang
    lower_pisang = np.array([20, 100, 100])
    upper_pisang = np.array([30, 250, 255])

    # Buat mask berdasarkan rentang nilai warna kuning
    masked = cv2.inRange(hsv, lower_pisang, upper_pisang)
    
    # Menghitung jumlah piksel kuning dalam mask
    yellow_pixels = cv2.countNonZero(masked)
    
    # Mencari kontur dari mask
    contours, _ = cv2.findContours(masked, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    max_area = 0
    max_contour = None
    
    # Mencari kontur kuning dengan luas terbesar
    for contour in contours:
        area = cv2.contourArea(contour)
        
        if area > max_area:
            max_area = area
            max_contour = contour
    
    # Mengekstrak bounding box dari kontur terbesar
    x, y, w, h = cv2.boundingRect(max_contour)
    
    # Menambahkan margin pada bounding rectangle
    margin = 50
    x1 = max(0, x - margin)
    y1 = max(0, y - margin)
    x2 = min(gambar.shape[1], x + w + margin)
    y2 = min(gambar.shape[0], y + h + margin)
    
    # Menghitung koordinat tengah bounding box
    center_x = (x1 + x2) // 2
    center_y = (y1 + y2) // 2
    
    # Mengubah posisi kotak berdasarkan koordinat tengah bounding box
    kotak_width = 50
    kotak_height = 70
    kotak_x1 = max(0, center_x - kotak_width // 2)
    kotak_y1 = max(0, center_y - kotak_height // 2)
    kotak_x2 = min(gambar.shape[1], center_x + kotak_width // 2)
    kotak_y2 = min(gambar.shape[0], center_y + kotak_height // 2)
    
    # Membuat kotak 
    kotak = np.zeros((kotak_height, kotak_width, 3), dtype=np.uint8)
    kotak[:kotak_y2-kotak_y1, :kotak_x2-kotak_x1] = gambar[kotak_y1:kotak_y1+kotak_y2-kotak_y1, kotak_x1:kotak_x1+kotak_x2-kotak_x1]

    return kotak

# %%
def segmentasi_buah_pisang(input_dir, output_dir):
    # Buat direktori output jika belum ada
    os.makedirs(output_dir, exist_ok=True)

    # Dapatkan daftar file dalam direktori input
    file_list = os.listdir(input_dir)

    # Melakukan segmentasi pada setiap file gambar
    for file_name in file_list:
        # Baca gambar
        gambar = cv2.imread(os.path.join(input_dir, file_name))

        # Memeriksa jumlah piksel dengan metode segmentasi HSV
        segmented_img = nyaripisangripe(gambar)

        # Ubah nama file hasil segmentasi
        segmented_file_name = "segmented_" + file_name

        # Simpan hasil segmentasi ke direktori output
        cv2.imwrite(os.path.join(output_dir, segmented_file_name), segmented_img)

        print(f"Segmentasi selesai: {file_name} -> {segmented_file_name}")

# Contoh penggunaan
input_directory = "T:/PCD/Banana_Condensed_Three_Cat/ripe"
output_directory = "T:/PCD/Banana_Condensed_Three_Cat/segrp"
segmentasi_buah_pisang(input_directory, output_directory)
# Out:
# Segmentasi selesai: ripe (10).jpg -> segmented_ripe (10).jpg
# Segmentasi selesai: ripe (100).jpg -> segmented_ripe (100).jpg
# Segmentasi selesai: ripe (101).jpg -> segmented_ripe (101).jpg
# Segmentasi selesai: ripe (102).jpg -> segmented_ripe (102).jpg
# Segmentasi selesai: ripe (103).jpg -> segmented_ripe (103).jpg
# Segmentasi selesai: ripe (104).jpg -> segmented_ripe (104).jpg
# Segmentasi selesai: ripe (105).jpg -> segmented_ripe (105).jpg
# Segmentasi selesai: ripe (106).jpg -> segmented_ripe (106).jpg
# Segmentasi selesai: ripe (107).jpg -> segmented_ripe (107).jpg
# Segmentasi selesai: ripe (108).jpg -> segmented_ripe (108).jpg
# Segmentasi selesai: ripe (109).jpg -> segmented_ripe (109).jpg
# Segmentasi selesai: ripe (11).jpg -> segmented_ripe (11).jpg
# Segmentasi selesai: ripe (110).jpg -> segmented_ripe (110).jpg
# Segmentasi selesai: ripe (111).jpg -> segmented_ripe (111).jpg
# Segmentasi selesai: ripe (112).jpg -> segmented_ripe (112).jpg
# Segmentasi selesai: ripe (113).jpg -> segmented_ripe (113).jpg
# Segmentasi selesai: ripe (114).jpg -> segmented_ripe (114).jpg
# Segmentasi selesai: ripe (115).jpg -> segmented_ripe (115).jpg
# Segmentasi selesai: ripe (116).jpg -> segmented_ripe (116).jpg
# Segmentasi selesai: ripe (117).jpg -> segmented_ripe (117).jpg
# Segmentasi selesai: ripe (118).jpg -> segmented_ripe (118).jpg
# Segmentasi selesai: ripe (119).jpg -> segmented_ripe (119).jpg
# Segmentasi selesai: ripe (12).jpg -> segmented_ripe (12).jpg
# Segmentasi selesai: ripe (120).jpg -> segmented_ripe (120).jpg
# Segmentasi selesai: ripe (121).jpg -> segmented_ripe (121).jpg
# Segmentasi selesai: ripe (122).jpg -> segmented_ripe (122).jpg
# Segmentasi selesai: ripe (123).jpg -> segmented_ripe (123).jpg
# Segmentasi selesai: ripe (124).jpg -> segmented_ripe (124).jpg
# Segmentasi selesai: ripe (125).jpg -> segmented_ripe (125).jpg
# Segmentasi selesai: ripe (126).jpg -> segmented_ripe (126).jpg
# Segmentasi selesai: ripe (127).jpg -> segmented_ripe (127).jpg
# Segmentasi selesai: ripe (128).jpg -> segmented_ripe (128).jpg
# Segmentasi selesai: ripe (129).jpg -> segmented_ripe (129).jpg
# Segmentasi selesai: ripe (13).jpg -> segmented_ripe (13).jpg
# Segmentasi selesai: ripe (130).jpg -> segmented_ripe (130).jpg
# Segmentasi selesai: ripe (131).jpg -> segmented_ripe (131).jpg
# Segmentasi selesai: ripe (132).jpg -> segmented_ripe (132).jpg
# Segmentasi selesai: ripe (133).jpg -> segmented_ripe (133).jpg
# Segmentasi selesai: ripe (134).jpg -> segmented_ripe (134).jpg
# Segmentasi selesai: ripe (135).jpg -> segmented_ripe (135).jpg
# Segmentasi selesai: ripe (136).jpg -> segmented_ripe (136).jpg
# Segmentasi selesai: ripe (137).jpg -> segmented_ripe (137).jpg
# Segmentasi selesai: ripe (138).jpg -> segmented_ripe (138).jpg
# Segmentasi selesai: ripe (139).jpg -> segmented_ripe (139).jpg
# Segmentasi selesai: ripe (14).jpg -> segmented_ripe (14).jpg
# Segmentasi selesai: ripe (140).jpg -> segmented_ripe (140).jpg
# Segmentasi selesai: ripe (141).jpg -> segmented_ripe (141).jpg
# Segmentasi selesai: ripe (142).jpg -> segmented_ripe (142).jpg
# Segmentasi selesai: ripe (143).jpg -> segmented_ripe (143).jpg
# Segmentasi selesai: ripe (144).jpg -> segmented_ripe (144).jpg
# Segmentasi selesai: ripe (145).jpg -> segmented_ripe (145).jpg
# Segmentasi selesai: ripe (146).jpg -> segmented_ripe (146).jpg
# Segmentasi selesai: ripe (147).jpg -> segmented_ripe (147).jpg
# Segmentasi selesai: ripe (148).jpg -> segmented_ripe (148).jpg
# Segmentasi selesai: ripe (149).jpg -> segmented_ripe (149).jpg
# Segmentasi selesai: ripe (15).jpg -> segmented_ripe (15).jpg
# Segmentasi selesai: ripe (150).jpg -> segmented_ripe (150).jpg
# Segmentasi selesai: ripe (151).jpg -> segmented_ripe (151).jpg
# Segmentasi selesai: ripe (152).jpg -> segmented_ripe (152).jpg
# Segmentasi selesai: ripe (153).jpg -> segmented_ripe (153).jpg
# Segmentasi selesai: ripe (154).jpg -> segmented_ripe (154).jpg
# Segmentasi selesai: ripe (155).jpg -> segmented_ripe (155).jpg
# Segmentasi selesai: ripe (156).jpg -> segmented_ripe (156).jpg
# Segmentasi selesai: ripe (157).jpg -> segmented_ripe (157).jpg
# Segmentasi selesai: ripe (158).jpg -> segmented_ripe (158).jpg
# Segmentasi selesai: ripe (159).jpg -> segmented_ripe (159).jpg
# Segmentasi selesai: ripe (16).jpg -> segmented_ripe (16).jpg
# Segmentasi selesai: ripe (160).jpg -> segmented_ripe (160).jpg
# Segmentasi selesai: ripe (161).jpg -> segmented_ripe (161).jpg
# Segmentasi selesai: ripe (162).jpg -> segmented_ripe (162).jpg
# Segmentasi selesai: ripe (163).jpg -> segmented_ripe (163).jpg
# Segmentasi selesai: ripe (164).jpg -> segmented_ripe (164).jpg
# Segmentasi selesai: ripe (165).jpg -> segmented_ripe (165).jpg
# Segmentasi selesai: ripe (166).jpg -> segmented_ripe (166).jpg
# Segmentasi selesai: ripe (167).jpg -> segmented_ripe (167).jpg
# Segmentasi selesai: ripe (168).jpg -> segmented_ripe (168).jpg
# Segmentasi selesai: ripe (169).jpg -> segmented_ripe (169).jpg
# Segmentasi selesai: ripe (17).jpg -> segmented_ripe (17).jpg
# Segmentasi selesai: ripe (170).jpg -> segmented_ripe (170).jpg
# Segmentasi selesai: ripe (171).jpg -> segmented_ripe (171).jpg
# Segmentasi selesai: ripe (172).jpg -> segmented_ripe (172).jpg
# Segmentasi selesai: ripe (173).jpg -> segmented_ripe (173).jpg
# Segmentasi selesai: ripe (174).jpg -> segmented_ripe (174).jpg
# Segmentasi selesai: ripe (175).jpg -> segmented_ripe (175).jpg
# Segmentasi selesai: ripe (176).jpg -> segmented_ripe (176).jpg
# Segmentasi selesai: ripe (177).jpg -> segmented_ripe (177).jpg
# Segmentasi selesai: ripe (178).jpg -> segmented_ripe (178).jpg
# Segmentasi selesai: ripe (179).jpg -> segmented_ripe (179).jpg
# Segmentasi selesai: ripe (18).jpg -> segmented_ripe (18).jpg
# Segmentasi selesai: ripe (180).jpg -> segmented_ripe (180).jpg
# Segmentasi selesai: ripe (181).jpg -> segmented_ripe (181).jpg
# Segmentasi selesai: ripe (182).jpg -> segmented_ripe (182).jpg
# Segmentasi selesai: ripe (183).jpg -> segmented_ripe (183).jpg
# Segmentasi selesai: ripe (184).jpg -> segmented_ripe (184).jpg
# Segmentasi selesai: ripe (185).jpg -> segmented_ripe (185).jpg
# Segmentasi selesai: ripe (186).jpg -> segmented_ripe (186).jpg
# Segmentasi selesai: ripe (187).jpg -> segmented_ripe (187).jpg
# Segmentasi selesai: ripe (188).jpg -> segmented_ripe (188).jpg
# Segmentasi selesai: ripe (189).jpg -> segmented_ripe (189).jpg
# Segmentasi selesai: ripe (19).jpg -> segmented_ripe (19).jpg
# Segmentasi selesai: ripe (190).jpg -> segmented_ripe (190).jpg
# Segmentasi selesai: ripe (191).jpg -> segmented_ripe (191).jpg
# Segmentasi selesai: ripe (192).jpg -> segmented_ripe (192).jpg
# Segmentasi selesai: ripe (193).jpg -> segmented_ripe (193).jpg
# Segmentasi selesai: ripe (194).jpg -> segmented_ripe (194).jpg
# Segmentasi selesai: ripe (195).jpg -> segmented_ripe (195).jpg
# Segmentasi selesai: ripe (196).jpg -> segmented_ripe (196).jpg
# Segmentasi selesai: ripe (197).jpg -> segmented_ripe (197).jpg
# Segmentasi selesai: ripe (198).jpg -> segmented_ripe (198).jpg
# Segmentasi selesai: ripe (199).jpg -> segmented_ripe (199).jpg
# Segmentasi selesai: ripe (2).jpg -> segmented_ripe (2).jpg
# Segmentasi selesai: ripe (20).jpg -> segmented_ripe (20).jpg
# Segmentasi selesai: ripe (200).jpg -> segmented_ripe (200).jpg
# Segmentasi selesai: ripe (201).jpg -> segmented_ripe (201).jpg
# Segmentasi selesai: ripe (202).jpg -> segmented_ripe (202).jpg
# Segmentasi selesai: ripe (203).jpg -> segmented_ripe (203).jpg
# Segmentasi selesai: ripe (204).jpg -> segmented_ripe (204).jpg
# Segmentasi selesai: ripe (205).jpg -> segmented_ripe (205).jpg
# Segmentasi selesai: ripe (206).jpg -> segmented_ripe (206).jpg
# Segmentasi selesai: ripe (207).jpg -> segmented_ripe (207).jpg
# Segmentasi selesai: ripe (208).jpg -> segmented_ripe (208).jpg
# Segmentasi selesai: ripe (209).jpg -> segmented_ripe (209).jpg
# Segmentasi selesai: ripe (21).jpg -> segmented_ripe (21).jpg
# Segmentasi selesai: ripe (210).jpg -> segmented_ripe (210).jpg
# Segmentasi selesai: ripe (211).jpg -> segmented_ripe (211).jpg
# Segmentasi selesai: ripe (212).jpg -> segmented_ripe (212).jpg
# Segmentasi selesai: ripe (213).jpg -> segmented_ripe (213).jpg
# Segmentasi selesai: ripe (214).jpg -> segmented_ripe (214).jpg
# Segmentasi selesai: ripe (215).jpg -> segmented_ripe (215).jpg
# Segmentasi selesai: ripe (216).jpg -> segmented_ripe (216).jpg
# Segmentasi selesai: ripe (217).jpg -> segmented_ripe (217).jpg
# Segmentasi selesai: ripe (218).jpg -> segmented_ripe (218).jpg
# Segmentasi selesai: ripe (219).jpg -> segmented_ripe (219).jpg
# Segmentasi selesai: ripe (22).jpg -> segmented_ripe (22).jpg
# Segmentasi selesai: ripe (220).jpg -> segmented_ripe (220).jpg
# Segmentasi selesai: ripe (221).jpg -> segmented_ripe (221).jpg
# Segmentasi selesai: ripe (222).jpg -> segmented_ripe (222).jpg
# Segmentasi selesai: ripe (223).jpg -> segmented_ripe (223).jpg
# Segmentasi selesai: ripe (224).jpg -> segmented_ripe (224).jpg
# Segmentasi selesai: ripe (225).jpg -> segmented_ripe (225).jpg
# Segmentasi selesai: ripe (226).jpg -> segmented_ripe (226).jpg
# Segmentasi selesai: ripe (227).jpg -> segmented_ripe (227).jpg
# Segmentasi selesai: ripe (228).jpg -> segmented_ripe (228).jpg
# Segmentasi selesai: ripe (229).jpg -> segmented_ripe (229).jpg
# Segmentasi selesai: ripe (23).jpg -> segmented_ripe (23).jpg
# Segmentasi selesai: ripe (230).jpg -> segmented_ripe (230).jpg
# Segmentasi selesai: ripe (231).jpg -> segmented_ripe (231).jpg
# Segmentasi selesai: ripe (232).jpg -> segmented_ripe (232).jpg
# Segmentasi selesai: ripe (233).jpg -> segmented_ripe (233).jpg
# Segmentasi selesai: ripe (234).jpg -> segmented_ripe (234).jpg
# Segmentasi selesai: ripe (235).jpg -> segmented_ripe (235).jpg
# Segmentasi selesai: ripe (236).jpg -> segmented_ripe (236).jpg
# Segmentasi selesai: ripe (237).jpg -> segmented_ripe (237).jpg
# Segmentasi selesai: ripe (238).jpg -> segmented_ripe (238).jpg
# Segmentasi selesai: ripe (239).jpg -> segmented_ripe (239).jpg
# Segmentasi selesai: ripe (24).jpg -> segmented_ripe (24).jpg
# Segmentasi selesai: ripe (240).jpg -> segmented_ripe (240).jpg
# Segmentasi selesai: ripe (241).jpg -> segmented_ripe (241).jpg
# Segmentasi selesai: ripe (242).jpg -> segmented_ripe (242).jpg
# Segmentasi selesai: ripe (243).jpg -> segmented_ripe (243).jpg
# Segmentasi selesai: ripe (244).jpg -> segmented_ripe (244).jpg
# Segmentasi selesai: ripe (245).jpg -> segmented_ripe (245).jpg
# Segmentasi selesai: ripe (246).jpg -> segmented_ripe (246).jpg
# Segmentasi selesai: ripe (247).jpg -> segmented_ripe (247).jpg
# Segmentasi selesai: ripe (248).jpg -> segmented_ripe (248).jpg
# Segmentasi selesai: ripe (249).jpg -> segmented_ripe (249).jpg
# Segmentasi selesai: ripe (25).jpg -> segmented_ripe (25).jpg
# Segmentasi selesai: ripe (250).jpg -> segmented_ripe (250).jpg
# Segmentasi selesai: ripe (251).jpg -> segmented_ripe (251).jpg
# Segmentasi selesai: ripe (252).jpg -> segmented_ripe (252).jpg
# Segmentasi selesai: ripe (253).jpg -> segmented_ripe (253).jpg
# Segmentasi selesai: ripe (254).jpg -> segmented_ripe (254).jpg
# Segmentasi selesai: ripe (255).jpg -> segmented_ripe (255).jpg
# Segmentasi selesai: ripe (256).jpg -> segmented_ripe (256).jpg
# Segmentasi selesai: ripe (257).jpg -> segmented_ripe (257).jpg
# Segmentasi selesai: ripe (258).jpg -> segmented_ripe (258).jpg
# Segmentasi selesai: ripe (259).jpg -> segmented_ripe (259).jpg
# Segmentasi selesai: ripe (26).jpg -> segmented_ripe (26).jpg
# Segmentasi selesai: ripe (260).jpg -> segmented_ripe (260).jpg
# Segmentasi selesai: ripe (261).jpg -> segmented_ripe (261).jpg
# Segmentasi selesai: ripe (262).jpg -> segmented_ripe (262).jpg
# Segmentasi selesai: ripe (263).jpg -> segmented_ripe (263).jpg
# Segmentasi selesai: ripe (264).jpg -> segmented_ripe (264).jpg
# Segmentasi selesai: ripe (265).jpg -> segmented_ripe (265).jpg
# Segmentasi selesai: ripe (266).jpg -> segmented_ripe (266).jpg
# Segmentasi selesai: ripe (267).jpg -> segmented_ripe (267).jpg
# Segmentasi selesai: ripe (268).jpg -> segmented_ripe (268).jpg
# Segmentasi selesai: ripe (269).jpg -> segmented_ripe (269).jpg
# Segmentasi selesai: ripe (27).jpg -> segmented_ripe (27).jpg
# Segmentasi selesai: ripe (270).jpg -> segmented_ripe (270).jpg
# Segmentasi selesai: ripe (271).jpg -> segmented_ripe (271).jpg
# Segmentasi selesai: ripe (272).jpg -> segmented_ripe (272).jpg
# Segmentasi selesai: ripe (273).jpg -> segmented_ripe (273).jpg
# Segmentasi selesai: ripe (274).jpg -> segmented_ripe (274).jpg
# Segmentasi selesai: ripe (275).jpg -> segmented_ripe (275).jpg
# Segmentasi selesai: ripe (276).jpg -> segmented_ripe (276).jpg
# Segmentasi selesai: ripe (277).jpg -> segmented_ripe (277).jpg
# Segmentasi selesai: ripe (278).jpg -> segmented_ripe (278).jpg
# Segmentasi selesai: ripe (279).jpg -> segmented_ripe (279).jpg
# Segmentasi selesai: ripe (28).jpg -> segmented_ripe (28).jpg
# Segmentasi selesai: ripe (280).jpg -> segmented_ripe (280).jpg
# Segmentasi selesai: ripe (281).jpg -> segmented_ripe (281).jpg
# Segmentasi selesai: ripe (282).jpg -> segmented_ripe (282).jpg
# Segmentasi selesai: ripe (283).jpg -> segmented_ripe (283).jpg
# Segmentasi selesai: ripe (284).jpg -> segmented_ripe (284).jpg
# Segmentasi selesai: ripe (285).jpg -> segmented_ripe (285).jpg
# Segmentasi selesai: ripe (286).jpg -> segmented_ripe (286).jpg
# Segmentasi selesai: ripe (287).jpg -> segmented_ripe (287).jpg
# Segmentasi selesai: ripe (288).jpg -> segmented_ripe (288).jpg
# Segmentasi selesai: ripe (289).jpg -> segmented_ripe (289).jpg
# Segmentasi selesai: ripe (29).jpg -> segmented_ripe (29).jpg
# Segmentasi selesai: ripe (290).jpg -> segmented_ripe (290).jpg
# Segmentasi selesai: ripe (291).jpg -> segmented_ripe (291).jpg
# Segmentasi selesai: ripe (292).jpg -> segmented_ripe (292).jpg
# Segmentasi selesai: ripe (293).jpg -> segmented_ripe (293).jpg
# Segmentasi selesai: ripe (294).jpg -> segmented_ripe (294).jpg
# Segmentasi selesai: ripe (295).jpg -> segmented_ripe (295).jpg
# Segmentasi selesai: ripe (296).jpg -> segmented_ripe (296).jpg
# Segmentasi selesai: ripe (297).jpg -> segmented_ripe (297).jpg
# Segmentasi selesai: ripe (298).jpg -> segmented_ripe (298).jpg
# Segmentasi selesai: ripe (299).jpg -> segmented_ripe (299).jpg
# Segmentasi selesai: ripe (3).jpg -> segmented_ripe (3).jpg
# Segmentasi selesai: ripe (30).jpg -> segmented_ripe (30).jpg
# Segmentasi selesai: ripe (300).jpg -> segmented_ripe (300).jpg
# Segmentasi selesai: ripe (301).jpg -> segmented_ripe (301).jpg
# Segmentasi selesai: ripe (302).jpg -> segmented_ripe (302).jpg
# Segmentasi selesai: ripe (303).jpg -> segmented_ripe (303).jpg
# Segmentasi selesai: ripe (304).jpg -> segmented_ripe (304).jpg
# Segmentasi selesai: ripe (305).jpg -> segmented_ripe (305).jpg
# Segmentasi selesai: ripe (306).jpg -> segmented_ripe (306).jpg
# Segmentasi selesai: ripe (307).jpg -> segmented_ripe (307).jpg
# Segmentasi selesai: ripe (308).jpg -> segmented_ripe (308).jpg
# Segmentasi selesai: ripe (309).jpg -> segmented_ripe (309).jpg
# Segmentasi selesai: ripe (31).jpg -> segmented_ripe (31).jpg
# Segmentasi selesai: ripe (310).jpg -> segmented_ripe (310).jpg
# Segmentasi selesai: ripe (311).jpg -> segmented_ripe (311).jpg
# Segmentasi selesai: ripe (312).jpg -> segmented_ripe (312).jpg
# Segmentasi selesai: ripe (313).jpg -> segmented_ripe (313).jpg
# Segmentasi selesai: ripe (314).jpg -> segmented_ripe (314).jpg
# Segmentasi selesai: ripe (315).jpg -> segmented_ripe (315).jpg
# Segmentasi selesai: ripe (316).jpg -> segmented_ripe (316).jpg
# Segmentasi selesai: ripe (317).jpg -> segmented_ripe (317).jpg
# Segmentasi selesai: ripe (318).jpg -> segmented_ripe (318).jpg
# Segmentasi selesai: ripe (319).jpg -> segmented_ripe (319).jpg
# Segmentasi selesai: ripe (32).jpg -> segmented_ripe (32).jpg
# Segmentasi selesai: ripe (320).jpg -> segmented_ripe (320).jpg
# Segmentasi selesai: ripe (321).jpg -> segmented_ripe (321).jpg
# Segmentasi selesai: ripe (322).jpg -> segmented_ripe (322).jpg
# Segmentasi selesai: ripe (323).jpg -> segmented_ripe (323).jpg
# Segmentasi selesai: ripe (324).jpg -> segmented_ripe (324).jpg
# Segmentasi selesai: ripe (325).jpg -> segmented_ripe (325).jpg
# Segmentasi selesai: ripe (326).jpg -> segmented_ripe (326).jpg
# Segmentasi selesai: ripe (327).jpg -> segmented_ripe (327).jpg
# Segmentasi selesai: ripe (328).jpg -> segmented_ripe (328).jpg
# Segmentasi selesai: ripe (329).jpg -> segmented_ripe (329).jpg
# Segmentasi selesai: ripe (33).jpg -> segmented_ripe (33).jpg
# Segmentasi selesai: ripe (330).jpg -> segmented_ripe (330).jpg
# Segmentasi selesai: ripe (331).jpg -> segmented_ripe (331).jpg
# Segmentasi selesai: ripe (332).jpg -> segmented_ripe (332).jpg
# Segmentasi selesai: ripe (333).jpg -> segmented_ripe (333).jpg
# Segmentasi selesai: ripe (334).jpg -> segmented_ripe (334).jpg
# Segmentasi selesai: ripe (335).jpg -> segmented_ripe (335).jpg
# Segmentasi selesai: ripe (336).jpg -> segmented_ripe (336).jpg
# Segmentasi selesai: ripe (337).jpg -> segmented_ripe (337).jpg
# Segmentasi selesai: ripe (338).jpg -> segmented_ripe (338).jpg
# Segmentasi selesai: ripe (339).jpg -> segmented_ripe (339).jpg
# Segmentasi selesai: ripe (34).jpg -> segmented_ripe (34).jpg
# Segmentasi selesai: ripe (340).jpg -> segmented_ripe (340).jpg
# Segmentasi selesai: ripe (341).jpg -> segmented_ripe (341).jpg
# Segmentasi selesai: ripe (342).jpg -> segmented_ripe (342).jpg
# Segmentasi selesai: ripe (343).jpg -> segmented_ripe (343).jpg
# Segmentasi selesai: ripe (344).jpg -> segmented_ripe (344).jpg
# Segmentasi selesai: ripe (35).jpg -> segmented_ripe (35).jpg
# Segmentasi selesai: ripe (36).jpg -> segmented_ripe (36).jpg
# Segmentasi selesai: ripe (37).jpg -> segmented_ripe (37).jpg
# Segmentasi selesai: ripe (38).jpg -> segmented_ripe (38).jpg
# Segmentasi selesai: ripe (39).jpg -> segmented_ripe (39).jpg
# Segmentasi selesai: ripe (4).jpg -> segmented_ripe (4).jpg
# Segmentasi selesai: ripe (40).jpg -> segmented_ripe (40).jpg
# Segmentasi selesai: ripe (41).jpg -> segmented_ripe (41).jpg
# Segmentasi selesai: ripe (42).jpg -> segmented_ripe (42).jpg
# Segmentasi selesai: ripe (43).jpg -> segmented_ripe (43).jpg
# Segmentasi selesai: ripe (44).jpg -> segmented_ripe (44).jpg
# Segmentasi selesai: ripe (45).jpg -> segmented_ripe (45).jpg
# Segmentasi selesai: ripe (46).jpg -> segmented_ripe (46).jpg
# Segmentasi selesai: ripe (47).jpg -> segmented_ripe (47).jpg
# Segmentasi selesai: ripe (48).jpg -> segmented_ripe (48).jpg
# Segmentasi selesai: ripe (49).jpg -> segmented_ripe (49).jpg
# Segmentasi selesai: ripe (5).jpg -> segmented_ripe (5).jpg
# Segmentasi selesai: ripe (50).jpg -> segmented_ripe (50).jpg
# Segmentasi selesai: ripe (51).jpg -> segmented_ripe (51).jpg
# Segmentasi selesai: ripe (52).jpg -> segmented_ripe (52).jpg
# Segmentasi selesai: ripe (53).jpg -> segmented_ripe (53).jpg
# Segmentasi selesai: ripe (54).jpg -> segmented_ripe (54).jpg
# Segmentasi selesai: ripe (55).jpg -> segmented_ripe (55).jpg
# Segmentasi selesai: ripe (56).jpg -> segmented_ripe (56).jpg
# Segmentasi selesai: ripe (57).jpg -> segmented_ripe (57).jpg
# Segmentasi selesai: ripe (58).jpg -> segmented_ripe (58).jpg
# Segmentasi selesai: ripe (59).jpg -> segmented_ripe (59).jpg
# Segmentasi selesai: ripe (6).jpg -> segmented_ripe (6).jpg
# Segmentasi selesai: ripe (60).jpg -> segmented_ripe (60).jpg
# Segmentasi selesai: ripe (61).jpg -> segmented_ripe (61).jpg
# Segmentasi selesai: ripe (62).jpg -> segmented_ripe (62).jpg
# Segmentasi selesai: ripe (63).jpg -> segmented_ripe (63).jpg
# Segmentasi selesai: ripe (64).jpg -> segmented_ripe (64).jpg
# Segmentasi selesai: ripe (65).jpg -> segmented_ripe (65).jpg
# Segmentasi selesai: ripe (66).jpg -> segmented_ripe (66).jpg
# Segmentasi selesai: ripe (67).jpg -> segmented_ripe (67).jpg
# Segmentasi selesai: ripe (68).jpg -> segmented_ripe (68).jpg
# Segmentasi selesai: ripe (69).jpg -> segmented_ripe (69).jpg
# Segmentasi selesai: ripe (7).jpg -> segmented_ripe (7).jpg
# Segmentasi selesai: ripe (70).jpg -> segmented_ripe (70).jpg
# Segmentasi selesai: ripe (71).jpg -> segmented_ripe (71).jpg
# Segmentasi selesai: ripe (72).jpg -> segmented_ripe (72).jpg
# Segmentasi selesai: ripe (73).jpg -> segmented_ripe (73).jpg
# Segmentasi selesai: ripe (74).jpg -> segmented_ripe (74).jpg
# Segmentasi selesai: ripe (75).jpg -> segmented_ripe (75).jpg
# Segmentasi selesai: ripe (76).jpg -> segmented_ripe (76).jpg
# Segmentasi selesai: ripe (77).jpg -> segmented_ripe (77).jpg
# Segmentasi selesai: ripe (78).jpg -> segmented_ripe (78).jpg
# Segmentasi selesai: ripe (79).jpg -> segmented_ripe (79).jpg
# Segmentasi selesai: ripe (8).jpg -> segmented_ripe (8).jpg
# Segmentasi selesai: ripe (80).jpg -> segmented_ripe (80).jpg
# Segmentasi selesai: ripe (81).jpg -> segmented_ripe (81).jpg
# Segmentasi selesai: ripe (82).jpg -> segmented_ripe (82).jpg
# Segmentasi selesai: ripe (83).jpg -> segmented_ripe (83).jpg
# Segmentasi selesai: ripe (84).jpg -> segmented_ripe (84).jpg
# Segmentasi selesai: ripe (85).jpg -> segmented_ripe (85).jpg
# Segmentasi selesai: ripe (86).jpg -> segmented_ripe (86).jpg
# Segmentasi selesai: ripe (87).jpg -> segmented_ripe (87).jpg
# Segmentasi selesai: ripe (88).jpg -> segmented_ripe (88).jpg
# Segmentasi selesai: ripe (89).jpg -> segmented_ripe (89).jpg
# Segmentasi selesai: ripe (9).jpg -> segmented_ripe (9).jpg
# Segmentasi selesai: ripe (90).jpg -> segmented_ripe (90).jpg
# Segmentasi selesai: ripe (91).jpg -> segmented_ripe (91).jpg
# Segmentasi selesai: ripe (92).jpg -> segmented_ripe (92).jpg
# Segmentasi selesai: ripe (93).jpg -> segmented_ripe (93).jpg
# Segmentasi selesai: ripe (94).jpg -> segmented_ripe (94).jpg
# Segmentasi selesai: ripe (95).jpg -> segmented_ripe (95).jpg
# Segmentasi selesai: ripe (96).jpg -> segmented_ripe (96).jpg
# Segmentasi selesai: ripe (97).jpg -> segmented_ripe (97).jpg
# Segmentasi selesai: ripe (98).jpg -> segmented_ripe (98).jpg
# Segmentasi selesai: ripe (99).jpg -> segmented_ripe (99).jpg
# Segmentasi selesai: ripe.jpg -> segmented_ripe.jpg
